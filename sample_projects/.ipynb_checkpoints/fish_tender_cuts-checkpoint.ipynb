# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import pandas as pd

# %%
url="https://tendercuts.in/category/sea-food"

# %%
page=urlopen(url)
html=page.read().decode('utf-8')

# %%
html
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>#1 Online Fresh Fish &amp; Seafood Market - TenderCuts.in</title><base href="/"><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no"><meta name="description" content="Best Formalin Free Fish &amp; Seafood Online. Safe Prawns delivered at your door in 120 minutes in Chennai &amp; Hyderabad. Antibiotic Free.100% Halal. Freshly Packed "><meta name="title" content="Order Meat Online | Buy Fresh Chicken &amp; Fish Online - TenderCuts.in"><link rel="icon" type="image/x-icon" href="favicon.ico"><link async="" href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"><script src="https://maps.googleapis.com/maps/api/js?v=3.exp&amp;libraries=places&amp;key=AIzaSyBGwX-cOb7BB4aJZaTFT7aD96LEQYdgRlw"></script><script src="https://webcdn.tendercuts.in/assets/js/intersect.js"></script><script async="" src="https://wchat.freshchat.com/js/widget.js"><
# ...

# %%
soup=BeautifulSoup(html,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
nameList=[]
for name in soup("mat-card-title"):
    nameList.append(name.text)
products=[nameList[x] for x in range(len(nameList)) if nameList[x] not in nameList[x+1:]]

# %%
products
# Out:
# ['Freshwater Pomfret - Yeri Vavval',
#  'Catla Large (800 Gms to 1.2 Kg)',
#  'Rohu Large (800 Gms to 1.2 Kg)',
#  'Black Pomfert /Karuppu Vavval',
#  'Indian Salmon/Kaala',
#  'Anchovy / Nethili (Medium)',
#  'Squid / Kanavai',
#  'Sardine - Mathi/Kavalai',
#  'Snapper/ Sankara - Medium',
#  'Sea Bass/Koduva',
#  'Emperor / Vilai Meen',
#  'Shark /Sura',
#  'Pearl Spot / Karimeen',
#  'Three Spot Crab / Kan Nandu',
#  'Tuna / Soorai',
#  'Trevally / Parai',
#  'Crab / Nandu',
#  'Silver Belly / Karai Podi',
#  'Indian Makerel/Ayila',
#  'Prawn / Eral ',
#  'Seer Fish / Vanjaram',
#  'Lady Fish/Kilangan',
#  'Prawns Medium - Deshelled [1 KG] ',
#  'Aar / Uppang Keluthi / Kattai Keluthi / Nei Keluthi',
#  'Fresh Norwegian Salmon',
#  'Bombay Duck',
#  'Red Mullet / Nagarai ',
#  'Stingray/Thirukkai  ',
#  'White Pomfert / White Vavval',
#  'Pabda',
#  'Tengra',
#  'Sea Butterfish / Kadal Viral',
#  'Hilsa Ilssa/Poi',
#  'Barracuda /Sheela',
# ...

# %%
weightList=[]
gross_weight=[]
net_weight=[]
weights=[]
for weight in soup.find_all("span",class_="callout"):
    weightList.append(weight.text.replace("\n",""))
for w in range(len(weightList)):
    if weightList[w].startswith("Gross"):
        gross_weight.append(weightList[w])
    elif weightList[w].startswith("Net"):
        net_weight.append(weightList[w])
    else:
        weights.append(weightList[w])

# %%
gross_weight
# Out:
# ['Gross: 500 - 700 gms',
#  'Gross: 800 - 1100 gms',
#  'Gross: 800 - 1100 gms',
#  'Gross: 400 - 600 gms',
#  'Gross: 800 - 1200 gms',
#  'Gross: 480 - 550 gms',
#  'Gross: 480 - 550 gms',
#  'Gross: 480 - 520 gms',
#  'Gross: 480 - 500 gms',
#  'Gross: 800 - 1200 gms',
#  'Gross: 500 - 700 gms',
#  'Gross: 480 - 510 gms',
#  'Gross: 480 - 600 gms',
#  'Gross: 480 - 600 gms',
#  'Gross: 900 - 1300 gms',
#  'Gross: 500 - 700 gms',
#  'Gross: 480 - 600 gms',
#  'Gross: 480 - 600 gms',
#  'Gross: 480 - 600 gms',
#  'Gross: 480 - 550 gms',
#  'Gross: 980 - 1000 gms',
#  'Gross: 950 - 1050 gms',
#  'Gross: 300 - 320 gms',
#  'Gross: 900 - 1000 gms',
#  'Gross: 480 - 600 gms',
#  'Gross: 1100 - 1200 gms',
#  'Gross: 480 - 550 gms',
#  'Gross: 480 - 500 gms',
#  'Gross: 480 - 500 gms',
#  'Gross: 490 - 510 gms',
#  'Gross: 700 - 900 gms',
#  'Gross: 400 - 600 gms',
#  'Gross: 480 - 500 gms',
#  'Gross: 950 - 1000 gms',
#  'Gross: 450 - 500 gms',
#  'Gross: 450 - 500 gms',
# ...

# %%
weights
# Out:
# [' Weight: Customizable', ' Weight: Customizable']

# %%
name = soup("mat-card-title")
product=[]
for i in range(len(name)):
    product.append(name[i].string)
productList=[product[x] for x in range(len(product)) if product[x] not in product[x+1:]]

# %%
len(productList)
# Out:
# 41

# %%
weight=soup("mat-card-content")
net_weights=[]
for j in range(len(weight)):
    weights=weight[j].get_text().replace("\n","")
    net_weights.append(re.sub("[:Weightms]","",weights))

# %%
weights=[]
try:
    for weight in soup.find_all("span",class_="callout"):
        weights.append(weight.text.replace("\n",""))
    gross_weight=[]
    net_weight=[]
    for w in weights:
        if w.startswith("Gross"):
            gross_weight.append(w)
        elif w.startswith("Net") or w.endswith(" Customizable"):
            net_weight.append(w)
except:
    for weight in soup.find_all("span",class_="callout"):
        weights.append(weight.text.replace("\n",""))

# %%
weight

# %%
price=soup.find("app-price-display")

# %%
price=[]
try:
    for rate in soup.find_all("p",class_="p-2 current-price bold price"):
        price.append(re.sub("[\s]","",rate.text))
except:
    for rate in soup.find_all("p",class_="current-price bold price"):
        price.append(re.sub("[\s]","",rate.text))
finally:
    for rate in soup.find_all("app-price-display"):
        cost=re.sub("[\s]","",rate.text)
        if cost[4:] not in price:
            price.append(cost)
priceList=[price[x] for x in range(len(price)) if price[x] not in price[x+1:]]

# %%
len(priceList)
# Out:
# 29

# %%
cost=[]
for p in soup("app-price-display"):
    cost.append(re.sub("[\s]","",p.text))
costList=[cost[x] for x in range(len(cost)) if cost[x] not in cost[x+1:]]

# %%
# Out:
# ['₹159₹139',
#  '₹269₹219',
#  '₹249₹199',
#  '₹589₹529',
#  '₹899₹849',
#  '₹289₹279',
#  '₹119',
#  '₹269₹249',
#  '₹799',
#  '₹459₹419',
#  '₹329₹309',
#  '₹339',
#  '₹519₹489',
#  '₹449₹419',
#  '₹219₹199',
#  'Startsfrom₹209',
#  'Startsfrom₹449',
#  '₹369₹329',
#  '₹529₹429',
#  '₹659',
#  '₹519',
#  '₹289₹269',
#  '₹259',
#  '₹749₹659',
#  '₹329',
#  '₹279',
#  '₹359₹319',
#  '₹1,999',
#  '₹379₹359',
#  '₹399₹379',
#  '₹369',
#  '₹189',
#  '₹239',
#  '₹139',
#  '₹349']

# %%
finalList=[]
for p in costList:
    op=p[4:]
    finalList.append(op)

# %%
finalList
# Out:
# ['₹139',
#  '₹219',
#  '₹199',
#  '₹529',
#  '₹849',
#  '₹279',
#  '',
#  '₹249',
#  '',
#  '₹419',
#  '₹309',
#  '',
#  '₹489',
#  '₹419',
#  '₹199',
#  'tsfrom₹209',
#  'tsfrom₹449',
#  '₹329',
#  '₹429',
#  '',
#  '',
#  '₹269',
#  '',
#  '₹659',
#  '',
#  '',
#  '₹319',
#  '99',
#  '₹359',
#  '₹379',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
len(finalList)
# Out:
# 35

# %%
totalList=[]
for k in finalList:
    totalList.append(k[4:])

# %%
for i in totalList:
    if i not in priceList:
        priceList.append(i)

# %%
len(priceList)
# Out:
# 50

# %%
price=[]
for rate in soup.find_all("p",class_="p-2 current-price bold price"):
    price.append(rate.text.replace("\n",""))
priceList1=[price[x] for x in range(len(price)) if price[x] not in price[x+1:]]

# %%
price2=[]
for rate in soup.find_all("p",class_="current-price bold price"):
    price2.append(rate.text.replace("\n",""))
priceList2=[price2[x] for x in range(len(price2)) if price2[x] not in price2[x+1:]]

# %%
len(priceList1)+len(priceList2)
# Out:
# 33

# %%
price=soup("span")

# %%
cost=soup("app-price-display")
net_price=[cost[k].get_text().replace("\n","") for k in range(len(cost)) if cost[k] not in cost[k+1:]]

# %%
prRX=re.compile(r"[0-9]+")

# %%
netP=[]
for netPrice in net_price:
    prObjs=prRX.findall(netPrice)
    netP.append(prObjs[-1])

print(netP)
# Out:
# ['139', '219', '199', '529', '849', '279', '249', '119', '249', '799', '419', '309', '339', '259', '339', '489', '419', '269', '199', '209', '449', '329', '429', '659', '519', '259', '269', '259', '659', '329', '279', '319', '999', '359', '379', '369', '189', '239', '349', '139', '349']

# %%
weightList1=[]
List=[]
for weight in soup.find_all("span",class_="callout"):
    weightList1.append(re.sub("[\s]","",weight.text))

# %%
weightRegex=re.compile(r"G(\w+):\d+\s-\s\d+")

# %%
grossWeights=[]
for weights in weightList1:
    g=weightRegex.findall(weight)
    grossWeights.append(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-a5bfb5306007> in <module>
#       1 grossWeights=[]
#       2 for weights in weightList1:
# ----> 3     g=weightRegex.findall(weight)
#       4     grossWeights.append(g)
#
# TypeError: expected string or bytes-like object

# %%
weightList1
# Out:
# ['Gross:500-700gms',
#  'Net:350-490gms',
#  'Gross:800-1100gms',
#  'Net:560-840gms',
#  'Gross:800-1100gms',
#  'Net:560-840gms',
#  'Gross:400-600gms',
#  'Net:280-420gms',
#  'Gross:800-1200gms',
#  'Net:560-840gms',
#  'Gross:480-550gms',
#  'Net:280-330gms',
#  'Gross:480-550gms',
#  'Net:240-270gms',
#  'Gross:480-520gms',
#  'Net:240-260gms',
#  'Gross:480-500gms',
#  'Net:330-420gms',
#  'Gross:800-1200gms',
#  'Net:560-840gms',
#  'Gross:500-700gms',
#  'Net:350-490gms',
#  'Gross:480-510gms',
#  'Net:480-510gms',
#  'Gross:480-600gms',
#  'Net:330-420gms',
#  'Gross:480-600gms',
#  'Net:NA',
#  'Gross:900-1300gms',
#  'Net:540-780gms',
#  'Gross:500-700gms',
#  'Net:300-420gms',
#  'Gross:480-600gms',
#  'Net:290-360gms',
#  'Gross:480-600gms',
#  'Net:300-500gms',
#  'Gross:480-600gms',
#  'Net:330-420gms',
#  'Weight:Customizable',
#  'Weight:Customizable',
#  'Gross:480-550gms',
#  'Net:310-360gms',
#  'Gross:980-1000gms',
#  'Net:480-500gms',
#  'Gross:950-1050gms',
# ...

# %%
len(netP)
# Out:
# 41

# %%
net_price
# Out:
# ['₹159    ₹139  ',
#  '₹269    ₹219  ',
#  '₹249    ₹199  ',
#  '₹589    ₹529  ',
#  '₹899    ₹849  ',
#  '₹289    ₹279  ',
#  '₹269    ₹249  ',
#  '      ₹119    ',
#  '₹269    ₹249  ',
#  '      ₹799    ',
#  '₹459    ₹419  ',
#  '₹329    ₹309  ',
#  '      ₹339    ',
#  '      ₹259    ',
#  '      ₹339    ',
#  '₹519    ₹489  ',
#  '₹449    ₹419  ',
#  '₹289    ₹269  ',
#  '₹219    ₹199  ',
#  'Starts from       ₹209    ',
#  'Starts from       ₹449    ',
#  '₹369    ₹329  ',
#  '₹529    ₹429  ',
#  '      ₹659    ',
#  '      ₹519    ',
#  '      ₹259    ',
#  '₹289    ₹269  ',
#  '      ₹259    ',
#  '₹749    ₹659  ',
#  '      ₹329    ',
#  '      ₹279    ',
#  '₹359    ₹319  ',
#  '      ₹1,999    ',
#  '₹379    ₹359  ',
#  '₹399    ₹379  ',
#  '      ₹369    ',
#  '      ₹189    ',
#  '      ₹239    ',
#  '      ₹349    ',
#  '      ₹139    ',
#  '      ₹349    ']

# %%
df=pd.DataFrame(productList,columns=['Name'])

# %%
df['Weight_in_gms']=pd.DataFrame(net_weights)

# %%
df['Selling_price'] = net_price

# %%
df
# Out:
#                                                  Name  \
# 0                    Freshwater Pomfret - Yeri Vavval
# 1                               Pearl Spot / Karimeen
# 2                           Snapper/ Sankara - Medium
# 3                                     Sea Bass/Koduva
# 4                       Black Pomfert /Karuppu Vavval
# 5                                     Squid / Kanavai
# 6                                Emperor / Vilai Meen
# 7                                    Trevally / Parai
# 8                         Three Spot Crab / Kan Nandu
# 9                                        Crab / Nandu
# 10                                      Prawn / Eral
# 11                               Seer Fish / Vanjaram
# 12                                 Lady Fish/Kilangan
# 13                  Prawns Medium - Deshelled [1 KG]
# 14                            Sardine - Mathi/Kavalai
# 15                                      Tuna / Soorai
# ...

# %%
path="C:/Users/Azeem/Documents/Projects/Python-Projects/excel/tender_cuts_fish.csv"
if os.path.isfile == True:
    pass
else:
    df.to_csv(path,index=False)

# %%
from bs4 import BeautifulSoup
import os
import re
import pandas as pd
import requests
import boto3

def Scraping(url):
    urlName=url.split("/")[4] #To get the product category (e.g.,chicken or mutton or etc.,)...
    product_link=requests.get(url).text
    soup=BeautifulSoup(product_link,'lxml') #Parsing the html using BeautifulSoup...
    name = soup("mat-card-title")
    product=[]
    for j in range(len(name)):
        product.append(name[j].string)
    product_name=[product[x] for x in range(len(product)) if product[x] not in product[x+1:]]
    weight=soup("mat-card-content")
    net_weights=[]
    for k in range(len(weight)):
        weights=weight[k].get_text().replace("\n","")
        net_weights.append(re.sub("[^gms\t-a-zA-Z]","",weights))
    price=soup("app-price-display")
    net_price=[re.sub("[^0-9Starts fromto]","",price[k].get_text()) for k in range(len(price)) if price[k] not in price[k+1:]]
    dynamodb=boto3.resource('dynamodb')
    table=dynamodb.Table('price_comparison')
    with table
    
#     df=pd.DataFrame(product_name,columns=['Name'])
#     df['Weight_in_gms']=pd.DataFrame(net_weights)
#     df['Selling_price'] = net_price
#     df['product_category'] = urlName
#     df=df[['product_category','Name','Weight_in_gms','Selling_price']] #Rearranging columns in the dataframe...
#     path=f'c:/python_projects/tendercuts/{urlName}.csv'
#     # To check if the file exists or not...
#     if os.path.isfile(path) == True:
#         print("file already exists...")
#     else:
#         print("creating new file...")
#         df.to_csv(path,index=False)
#     print("Done!!!")
#     return df

# %%
Scraping(url='https://tendercuts.in/category/sea-food')
# Out:
# creating new file...
# Done!!!
#    product_category                                               Name  \
# 0          sea-food                     Rohu Large (800 Gms to 1.2 Kg)
# 1          sea-food                            Sardine - Mathi/Kavalai
# 2          sea-food                      Black Pomfert /Karuppu Vavval
# 3          sea-food                              Pearl Spot / Karimeen
# 4          sea-food                               Emperor / Vilai Meen
# 5          sea-food                                   Trevally / Parai
# 6          sea-food                                      Tuna / Soorai
# 7          sea-food                                       Crab / Nandu
# 8          sea-food                                      Prawn / Eral
# 9          sea-food                               Seer Fish / Vanjaram
# 10         sea-food                  Prawns Medium - Deshelled [1 KG]
# 11         sea-food                                  Barracuda /Sheela
# ...

# %%
import boto3

# %%
dynamodb=boto3.resource('dynamodb')

# %%
table=dynamodb.Table('price_comparison')

# %%
table
# Out:
# dynamodb.Table(name='price_comparison')

# %%
product
# Out:
# ['Freshwater Pomfret - Yeri Vavval',
#  'Trevally / Parai',
#  'Black Pomfert /Karuppu Vavval',
#  'Snapper/ Sankara - Medium',
#  'Crab / Nandu',
#  'Sardine - Mathi/Kavalai',
#  'Emperor / Vilai Meen',
#  'Squid / Kanavai',
#  'Shark /Sura',
#  'Anchovy / Nethili (Medium)']

# %%
with table.batch_writer() as batch:
    for i in range(len(product)):
        response=batch.put_item(Item={
        'CTM_StdText':product[i]
#         'Weight':net_weights[i],
 #        'Price':net_price[i]
        })
        print(response)

# %%
for i in range(len(product)):
    table.put_item(Item={
        'CTM_StdText':product,
        #'Weights':net_weights[i],
        #'Price':net_price[i]
     })

# %%
client=boto3.client(aws_access_key_id=,aws_secret_access_key=,service_name='dynamodb')

# %%
for i in range(len(productList)):    
    response=client.batch_write_item(RequestItems={
        'price_comparison':[
            {
                'PutRequest':{
                    'Item':{
                        'CTM_StdText':{
                            'S':productList[i],
                        }
                        'Price':{
                            'S':net_price[i],
                        }
                        'Weight':{
                            'S':net_weights[i]
                        }
                    }

                }
                    }
        ]
        })
# Out:
#   File "<ipython-input-37-192fe05d74cc>", line 10
#     'Price':{
#           ^
# SyntaxError: invalid syntax
