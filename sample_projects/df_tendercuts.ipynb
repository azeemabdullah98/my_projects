# %%
import pandas as pd

# %%
from datetime import datetime
forPrdFrom=datetime.now().strftime('%d-%m-%Y')

# %%
columns=['Type','Product Code','Context','Text']

# %%
len(columnNames)
# Out:
# 18

# %%
cc=pd.read_csv("c:/python_projects/fipola/mm.csv")

# %%
cc.fillna(value='-',inplace=True)

# %%
cc.drop(columns=['Weight','Price','Gross Weight','Net Weight'],inplace=True)

# %%
cc['ForPrd From'] = forPrdFrom

# %%
df=pd.read_csv("c:/python_projects/tendercuts/tec1.csv", index_col=False)

# %%
cc['Access ID'] = df['Access ID']

# %%
cc['ForPrd To']= '-'

# %%
cc.head
# Out:
#        Context         Type  \
# 0   tendercuts          dry
# 1   tendercuts          dry
# 2   tendercuts          dry
# 3   tendercuts          dry
# 4   tendercuts          dry
# 5   tendercuts          dry
# 6   tendercuts          dry
# 7   tendercuts  combo-packs
# 8   tendercuts  combo-packs
# 9   tendercuts  combo-packs
# 10  tendercuts  combo-packs
# 11  tendercuts  combo-packs
# 12  tendercuts  combo-packs
# 13  tendercuts  combo-packs
# 14  tendercuts  combo-packs
# 15  tendercuts  combo-packs
# 16  tendercuts  combo-packs
# 17  tendercuts  combo-packs
# 18  tendercuts  combo-packs
# 19  tendercuts  combo-packs
# 20  tendercuts  combo-packs
# 21  tendercuts  combo-packs
# 22  tendercuts      chicken
# 23  tendercuts      chicken
# 24  tendercuts      chicken
# 25  tendercuts      chicken
# 26  tendercuts      chicken
# 27  tendercuts      chicken
# 28  tendercuts      chicken
# 29  tendercuts      chicken
# 30  tendercuts      chicken
# 31  tendercuts      chicken
# ...

# %%
cc=cc.rename(columns=({'Product Name':'Text'}))

# %%
cc
# Out:
#         Context            Type                                  Text  \
# 0    tendercuts             dry                    Dry Prawns ( 80g )
# 1    tendercuts             dry  Dry Nethili Fish ( Small Anchovies )
# 2    tendercuts             dry                       Dry Ribbon Fish
# 3    tendercuts             dry                         Dry Seer Fish
# 4    tendercuts             dry                        Dry Shark Fish
# ..          ...             ...                                   ...
# 182  tendercuts  sauces-spreads                     Chilli Mayonnaise
# 183  tendercuts  sauces-spreads     Carrot & Cucumber Sandwich Spread
# 184  tendercuts  sauces-spreads                  Truly Tomato Ketchup
# 185  tendercuts  sauces-spreads                        Barbeque Sauce
# 186  tendercuts  sauces-spreads       Hot Garlic Stir Fry Sauce & Dip
#
#                 StdText Std Class1 Std Class2 Std Class3 Std Class4  \
# ...

# %%
cc.drop(columns='Unit of Measurement',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-c483a7375ce5> in <module>
# ----> 1 cc.drop(columns='Unit of Measurement',inplace=True)
#
# c:\python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# c:\python37\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# c:\python37\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
cc.to_csv("c:/python_projects/fipola/TMM.csv",index=False)

# %%
cc=cc.rename(columns=({'StdText':'Std Text'}))

# %%
cc=cc[['Type','Product Code','Context','Access ID','Text','ForPrd From','ForPrd To','Std Text','Std Class1','Std Class2','Std Class3','Std Class4','Std Class5']]

# %%
columnNames=['Type',
             'Product Code', 
             'Context', 
             'Access ID', 
             'Version', 
             'Text',
             'ForPrd From',
             'ForPrd To', 
             'InPrd From', 
             'InPrd To', 
             'Std Text',
             'Std Class1',
             'Std Class2', 
             'Std Class3', 
             'Std Class4', 
             'Std Class5', 
             'Std Class6',
             'Std Class7',]

# %%
cc.to_csv("c:/python_projects/fipola/TMM.csv",index=False)

# %%
mm=pd.read_csv("fipola/TMM.csv")

# %%
mm
# Out:
#                Type  Product Code     Context  \
# 0               dry        200004  tendercuts
# 1               dry        200029  tendercuts
# 2               dry        200102  tendercuts
# 3               dry        200103  tendercuts
# 4               dry        200104  tendercuts
# ..              ...           ...         ...
# 182  sauces-spreads        220020  tendercuts
# 183  sauces-spreads        200005  tendercuts
# 184  sauces-spreads        200100  tendercuts
# 185  sauces-spreads        200101  tendercuts
# 186  sauces-spreads        200006  tendercuts
#
#                             Access ID                                  Text  \
# 0               tendercuts/dry/200004                    Dry Prawns ( 80g )
# 1               tendercuts/dry/200004  Dry Nethili Fish ( Small Anchovies )
# 2               tendercuts/dry/200004                       Dry Ribbon Fish
# 3               tendercuts/dry/200004                         Dry Seer Fish
# ...

# %%
"Tendercuts/chicken/200004"
