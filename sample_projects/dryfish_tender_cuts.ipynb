# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import pandas as pd
import os

# %%
url="https://tendercuts.in/product/premium-chicken-strips-boneless"

# %%
page=urlopen(url)
html=page.read().decode()

# %%
html
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>Order Meat Online | Buy Fresh Chicken &amp; Fish Online - TenderCuts.in</title><base href="/"><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no"><meta name="description" content="Order tender,fresh, juicy &amp; safe meat &amp; seafood online from India\'s best online shop.           Get products delivered to your homes in Chennai &amp; Hyderabad."><meta name="title" content="Order Meat Online | Buy Fresh Chicken &amp; Fish Online - TenderCuts.in"><link rel="icon" type="image/x-icon" href="favicon.ico"><link async="" href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"><script src="https://maps.googleapis.com/maps/api/js?v=3.exp&amp;libraries=places&amp;key=AIzaSyBGwX-cOb7BB4aJZaTFT7aD96LEQYdgRlw"></script><script src="https://webcdn.tendercuts.in/assets/js/intersect.js"></script><script async="" src="https://wchat.freshchat.com/js/widget.js"></script><!-- uncomment the below line to enable card payment in local --><!-- <script type="text/javascript" src="https://sandbox.juspay.in/pay-v3.js"></script> --><!-- Global site tag (gtag.js) - Google Ads: 867485881 --><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-867485881"></script><script>window.dataLayer = window.dataLayer || [];\n    function gtag() { dataLayer.push(arguments); }\n    gtag(\'js\', new Date());\n    gtag(\'config\', \'AW-867485881\');</script><!-- End of Gtag --><!-- Google analaytics --><script>(function (i, s, o, g, r, a, m) {\n      i[\'GoogleAnalyticsObject\'] = r;\n      i[r] = i[r] || function () {\n        (i[r].q = i[r].q || []).push(arguments)\n      }, i[r].l = 1 * new Date();\n      a = s.createElement(o),\n        m = s.getElementsByTagName(o)[0];\n      a.async = 1;\n      a.src = g;\n      m.parentNode.insertBefore(a, m)\n    })(window, document, \'script\', \'https://www.google-analytics.com/analytics.js\', \'ga\');\n\n    ga(\'create\', \'UA-73682605-3\', \'auto\');\n    ga(\'send\', \'pageview\');\n    ga(\'require\', \'ec\');</script><!-- End Google Analytics --><!-- Facebook Pixel Code --><script>!function (f, b, e, v, n, t, s) {\n      if (f.fbq) return; n = f.fbq = function () {\n        n.callMethod ?\n          n.callMethod.apply(n, arguments) : n.queue.push(arguments)\n      };\n      if (!f._fbq) f._fbq = n; n.push = n; n.loaded = !0; n.version = \'2.0\';\n      n.queue = []; t = b.createElement(e); t.async = !0;\n      t.src = v; s = b.getElementsByTagName(e)[0];\n      s.parentNode.insertBefore(t, s)\n    }(window, document, \'script\',\n      \'https://connect.facebook.net/en_US/fbevents.js\');\n    fbq(\'init\', \'789852048536233\');\n    fbq(\'init\', \'666477300866892\');\n    fbq(\'track\', \'PageView\');</script><noscript><img height="1" width="1" src="https://www.facebook.com/tr?id=789852048536233&ev=PageView\n       &noscript=1"/></noscript><!-- End Facebook Pixel Code --><!-- Firebase Analytics --><script src="https://www.gstatic.com/firebasejs/8.6.7/firebase.js"></script><script>var firebaseConfig = {\n      apiKey: "AIzaSyC8WpNwHGsJokT9AL8kSCgpXh-w_oYlz4s",\n      authDomain: "tendercuts-d9c26.firebaseapp.com",\n      databaseURL: "https://tendercuts-d9c26.firebaseio.com",\n      projectId: "tendercuts-d9c26",\n      storageBucket: "tendercuts-d9c26.appspot.com",\n      messagingSenderId: "510314710553",\n      appId: "1:510314710553:web:6cadd9944e5085e987cc88",\n      measurementId: "G-51TPB0LZX3",\n    };\n    firebase.initializeApp(firebaseConfig);</script><!-- Firebase Analytics End--><script>// load Branch\n    (function (b, r, a, n, c, h, _, s, d, k) { if (!b[n] || !b[n]._q) { for (; s < _.length;)c(h, _[s++]); d = r.createElement(a); d.async = 1; d.src = "https://cdn.branch.io/branch-latest.min.js"; k = r.getElementsByTagName(a)[0]; k.parentNode.insertBefore(d, k); b[n] = h } })(window, document, "script", "branch", function (b, r) { b[r] = f ...

# %%
soup=BeautifulSoup(html,"lxml")

# %%
soup("h3")
# Out:
# [<h3 _ngcontent-c25="" class="product-name" color="primary">Premium Chicken-Strips (Boneless)</h3>,
#  <h3 _ngcontent-c7="">"A dose of kindness on your plate"</h3>]

# %%
name = soup("mat-card-title")

# %%
name
# Out:
# [<mat-card-title class="mat-card-title ng-tns-c9-3">Premium Chicken-Strips (Boneless)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-3">Premium Chicken-Strips (Boneless)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-4">Premium Chicken-Supreme (Boneless)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-4">Premium Chicken-Supreme (Boneless)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-5">Chicken Curry Cut (Skin On)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-5">Chicken Curry Cut (Skin On)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-6">Chicken Curry Cut (Skin Off)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-6">Chicken Curry Cut (Skin Off)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-7">Chicken Biryani Cut - Skin On</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-7">Chicken Biryani Cut - Skin On</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-8">Chicken Biryani Cut - Skinless</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-8">Chicken Biryani Cut - Skinless</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-9">Minced Chicken</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-9">Minced Chicken</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-10">Chicken Breast Boneless</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-10">Chicken Breast Boneless</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-11">Chicken Boneless (Cubes)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-11">Chicken Boneless (Cubes)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-12">Chicken Drumsticks</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-12">Chicken Drumsticks</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-13">Chicken Whole Leg</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-13">Chicken Whole Leg</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-14">Chicken Liver</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-14">Chicken Liver</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-15">Chicken Thigh &amp; Leg (Boneless) </mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-15">Chicken Thigh &amp; Leg (Boneless) </mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-16">Country Chicken</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-16">Country Chicken</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-17">Chicken Boneless (Cubes) (1 Kg)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-17">Chicken Boneless (Cubes) (1 Kg)</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-18">Chicken Wings</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-18">Chicken Wings</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-19">Chicken Lollipop</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-19">Chicken Lollipop</mat-card-title>]

# %%
name = soup("mat-card-title")
product=[]
for i in range(len(name)):
    product.append(name[i].string)
productList=[product[x] for x in range(len(product)) if product[x] not in product[x+1:]]

# %%
productList
# Out:
# ['Premium Chicken-Strips (Boneless)',
#  'Premium Chicken-Supreme (Boneless)',
#  'Chicken Curry Cut (Skin On)',
#  'Chicken Curry Cut (Skin Off)',
#  'Chicken Biryani Cut - Skin On',
#  'Chicken Biryani Cut - Skinless',
#  'Minced Chicken',
#  'Chicken Breast Boneless',
#  'Chicken Boneless (Cubes)',
#  'Chicken Drumsticks',
#  'Chicken Whole Leg',
#  'Chicken Liver',
#  'Chicken Thigh & Leg (Boneless) ',
#  'Country Chicken',
#  'Chicken Boneless (Cubes) (1 Kg)',
#  'Chicken Wings',
#  'Chicken Lollipop']

# %%
weight=soup("mat-card-content")
net_weights=[]
for j in range(len(weight)):
    weights=weight[j].get_text().replace("\n","")
    net_weights.append(re.sub("[:Weightms]","",weights))

# %%
net_weights
# Out:
# ['  330 - 350 ',
#  '  330 - 350 ',
#  '  Cuozabl',
#  '  Cuozabl',
#  '  480 - 500 ',
#  '  480 - 500 ',
#  '  480 - 500 ',
#  '  240 - 280 ',
#  '  480 - 500 ',
#  '  280 - 360 ',
#  '  370 - 390 ',
#  '  190 - 210 ',
#  '  480 - 500 ',
#  '  Cuozabl',
#  '  980 - 1000 ',
#  '  480 - 500 ',
#  '  280 - 300 ',
#  '"A do of kndn on your pla"']

# %%
price=soup("app-price-display")
net_price=[price[k].get_text().replace("\n","") for k in range(len(price)) if price[k] not in price[k+1:]]

# %%
net_price
# Out:
# ['      ₹175    ',
#  '₹185    ₹169  ',
#  'Starts from       ₹105    ',
#  'Starts from       ₹114    ',
#  '      ₹119    ',
#  '      ₹129    ',
#  '      ₹249    ',
#  '      ₹135    ',
#  '      ₹245    ',
#  '      ₹125    ',
#  '      ₹139    ',
#  '      ₹35    ',
#  '      ₹225    ',
#  'Starts from       ₹399    ',
#  '      ₹489    ',
#  '₹125    ₹115  ',
#  '₹99    ₹89  ']

# %%
df=pd.DataFrame(productList,columns=['Name'])

# %%
df['Weight_in_gms']=pd.DataFrame(net_weights)

# %%
df['Selling_price'] = net_price

# %%
df
# Out:
#                                    Name Weight_in_gms   Selling_price
# 0                         Dry Seer Fish        1 Pack        ₹120
# 1                       Dry Ribbon Fish        1 Pack         ₹60
# 2    Dry Nethili Fish ( Big Anchovies )        1 Pack        ₹120
# 3                         Dry Sole Fish        1 Pack         ₹50
# 4                        Dry Shark Fish        1 Pack         ₹70
# 5  Dry Nethili Fish ( Small Anchovies )        1 Pack         ₹60
# 6                    Dry Prawns ( 80g )        1 Pack         ₹75

# %%
path="C:/Users/Azeem/Documents/Projects/Python-Projects/excel/tender_cuts_dryfish.csv"
if os.path.isfile == True:
    pass
else:
    df.to_csv(path,index=False)
