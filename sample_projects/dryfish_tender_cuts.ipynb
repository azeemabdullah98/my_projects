# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import pandas as pd
import os

# %%
url="https://tendercuts.in/category/dry"

# %%
page=urlopen(url)
html=page.read().decode('utf-8')

# %%
html
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>Order Meat Online | Buy Fresh Chicken &amp; Fish Online - TenderCuts.in</title><base href="/"><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no"><meta name="description" content="Order tender, fresh, juicy &amp; safe meat &amp; seafood online from India\'s best online shop. Get products delivered to your homes in Chennai &amp; Hyderabad."><meta name="title" content="Order Meat Online | Buy Fresh Chicken &amp; Fish Online - TenderCuts.in"><link rel="icon" type="image/x-icon" href="favicon.ico"><link async="" href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"><script src="https://maps.googleapis.com/maps/api/js?v=3.exp&amp;libraries=places&amp;key=AIzaSyBGwX-cOb7BB4aJZaTFT7aD96LEQYdgRlw"></script><script src="https://webcdn.tendercuts.in/assets/js/intersect.js"></script><script async="" src="https://wchat.freshchat.com/js/widget.js"></script><!-- uncomment the below line to enable card payment in local --><!-- <script type="text/javascript" src="https://sandbox.juspay.in/pay-v3.js"></script> --><!-- Global site tag (gtag.js) - Google Ads: 867485881 --><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-867485881"></script><script>window.dataLayer = window.dataLayer || [];\n    function gtag() { dataLayer.push(arguments); }\n    gtag(\'js\', new Date());\n    gtag(\'config\', \'AW-867485881\');</script><!-- End of Gtag --><!-- Google analaytics --><script>(function (i, s, o, g, r, a, m) {\n      i[\'GoogleAnalyticsObject\'] = r;\n      i[r] = i[r] || function () {\n        (i[r].q = i[r].q || []).push(arguments)\n      }, i[r].l = 1 * new Date();\n      a = s.createElement(o),\n        m = s.getElementsByTagName(o)[0];\n      a.async = 1;\n      a.src = g;\n      m.parentNode.insertBefore(a, m)\n    })(window, document, \'script\', \'https://www.google-analytics.com/analytics.js\', \'ga\');\n\n    ga(\'create\', \'UA-73682605-3\', \'auto\');\n    ga(\'send\', \'pageview\');\n    ga(\'require\', \'ec\');</script><!-- End Google Analytics --><!-- Facebook Pixel Code --><script>!function (f, b, e, v, n, t, s) {\n      if (f.fbq) return; n = f.fbq = function () {\n        n.callMethod ?\n          n.callMethod.apply(n, arguments) : n.queue.push(arguments)\n      };\n      if (!f._fbq) f._fbq = n; n.push = n; n.loaded = !0; n.version = \'2.0\';\n      n.queue = []; t = b.createElement(e); t.async = !0;\n      t.src = v; s = b.getElementsByTagName(e)[0];\n      s.parentNode.insertBefore(t, s)\n    }(window, document, \'script\',\n      \'https://connect.facebook.net/en_US/fbevents.js\');\n    fbq(\'init\', \'789852048536233\');\n    fbq(\'init\', \'666477300866892\');\n    fbq(\'track\', \'PageView\');</script><noscript><img height="1" width="1" src="https://www.facebook.com/tr?id=789852048536233&ev=PageView\n       &noscript=1"/></noscript><!-- End Facebook Pixel Code --><script>// load Branch\n    (function (b, r, a, n, c, h, _, s, d, k) { if (!b[n] || !b[n]._q) { for (; s < _.length;)c(h, _[s++]); d = r.createElement(a); d.async = 1; d.src = "https://cdn.branch.io/branch-latest.min.js"; k = r.getElementsByTagName(a)[0]; k.parentNode.insertBefore(d, k); b[n] = h } })(window, document, "script", "branch", function (b, r) { b[r] = function () { b._q.push([r, arguments]) } }, { _q: [], _v: 1 }, "addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "), 0);</script><style>html,\n    body {\n      height: 100%;\n    }\n\n    #fc_frame,\n    #fc_frame.fc-widget-normal {\n      z-index: 100 !important;\n    }\n\n    @media (max-width: 575.98px) {\n\n      #fc_frame,\n      #fc_frame.fc-widget-normal {\n        display: none;\n      }\n\ ...

# %%
soup=BeautifulSoup(html,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><title>Order Meat Online | Buy Fresh Chicken &amp; Fish Online - TenderCuts.in</title><base href="/"/><meta content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/><meta content="Order tender, fresh, juicy &amp; safe meat &amp; seafood online from India's best online shop. Get products delivered to your homes in Chennai &amp; Hyderabad." name="description"/><meta content="Order Meat Online | Buy Fresh Chicken &amp; Fish Online - TenderCuts.in" name="title"/><link href="favicon.ico" rel="icon" type="image/x-icon"/><link async="" href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/><script src="https://maps.googleapis.com/maps/api/js?v=3.exp&amp;libraries=places&amp;key=AIzaSyBGwX-cOb7BB4aJZaTFT7aD96LEQYdgRlw"></script><script src="https://webcdn.tendercuts.in/assets/js/intersect.js"></script><script async="" src="https://wchat.freshchat.com/js/widget.js"></script><!-- uncomment the below line to enable card payment in local --><!-- <script type="text/javascript" src="https://sandbox.juspay.in/pay-v3.js"></script> --><!-- Global site tag (gtag.js) - Google Ads: 867485881 --><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-867485881"></script><script>window.dataLayer = window.dataLayer || [];
#     function gtag() { dataLayer.push(arguments); }
#     gtag('js', new Date());
#     gtag('config', 'AW-867485881');</script><!-- End of Gtag --><!-- Google analaytics --><script>(function (i, s, o, g, r, a, m) {
#       i['GoogleAnalyticsObject'] = r;
#       i[r] = i[r] || function () {
#         (i[r].q = i[r].q || []).push(arguments)
#       }, i[r].l = 1 * new Date();
#       a = s.createElement(o),
#         m = s.getElementsByTagName(o)[0];
#       a.async = 1;
#       a.src = g;
#       m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#     ga('create', 'UA-73682605-3', 'auto');
#     ga('send', 'pageview');
#     ga('require', 'ec');</script><!-- End Google Analytics --><!-- Facebook Pixel Code --><script>!function (f, b, e, v, n, t, s) {
#       if (f.fbq) return; n = f.fbq = function () {
#         n.callMethod ?
#           n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#       };
#       if (!f._fbq) f._fbq = n; n.push = n; n.loaded = !0; n.version = '2.0';
#       n.queue = []; t = b.createElement(e); t.async = !0;
#       t.src = v; s = b.getElementsByTagName(e)[0];
#       s.parentNode.insertBefore(t, s)
#     }(window, document, 'script',
#       'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '789852048536233');
#     fbq('init', '666477300866892');
#     fbq('track', 'PageView');</script><noscript><img height="1" src="https://www.facebook.com/tr?id=789852048536233&amp;ev=PageView
#        &amp;noscript=1" width="1"/></noscript><!-- End Facebook Pixel Code --><script>// load Branch
#     (function (b, r, a, n, c, h, _, s, d, k) { if (!b[n] || !b[n]._q) { for (; s < _.length;)c(h, _[s++]); d = r.createElement(a); d.async = 1; d.src = "https://cdn.branch.io/branch-latest.min.js"; k = r.getElementsByTagName(a)[0]; k.parentNode.insertBefore(d, k); b[n] = h } })(window, document, "script", "branch", function (b, r) { b[r] = function () { b._q.push([r, arguments]) } }, { _q: [], _v: 1 }, "addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "), 0);</script><style>html,
#     body {
#       height: 100%;
#     }
#
#     #fc_frame,
#     #fc_frame.fc-widget-normal {
#       z-index: 100 !important;
#     }
#
#     @media (max-width: 575.98px) {
#
#       #fc_frame,
#       #fc_frame.fc-widget-normal {
#         display: none;
#       }
#
#     }</style><!-- Google Tag Manager --><script>(function (w, d, s, l, i) {
#       w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#           new Date().getTime(), event: 'gtm.js'
#       }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#           'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-W94V6RP');</script><!-- End Google Tag Manager --><link href="https://webcdn.tendercuts.in/styles.3ecaf160dd8d2b7c1c0b.bundle.css" rel="stylesheet"/><style ng-transition="tcuts-web">.cdk-overlay-transparent-backdrop.cdk-overlay-backdrop-showing[_ngcontent-c0]{background-color:rgba(0,0,0,.2);opacity:1}.appheader[_ngcontent-c0]{margin-bottom:16px}p[_ngcontent-c0]{color:#7e808c;font-size:13px}.container[_ngcontent-c0]   h5[_ngcontent-c0]{margin-bottom:30px}.total-container[_ngcontent-c0]{border-top:1px solid #f2f2f2;padding:16px 16px 6px}.container[_ngcontent-c0]{width:100%;max-width:1200px;margin:0 auto;padding:0}.container[_ngcontent-c0]   .mat-drawer-container[_ngcontent-c0]{background-color:#fff}.container[_ngcontent-c0]   #address-drawer[_ngcontent-c0]{width:100%;padding:2%}@media (min-width:992px){.container[_ngcontent-c0]   #address-drawer[_ngcontent-c0]{width:30%;padding:1%}}.container[_ngcontent-c0]   button[mat-raised-button][_ngcontent-c0]{color:#fff;text-transform:uppercase;line-height:34px;font-weight:600;padding:0 24px}.container[_ngcontent-c0]   button[mat-raised-button][color=secondary][_ngcontent-c0]{background:#2e7d32}.container[_ngcontent-c0]   button[mat-raised-button][color=primary][_ngcontent-c0]{background:#b71c1c}.container[_ngcontent-c0]   .row.custom-no-gutters[_ngcontent-c0]{margin-right:0;margin-left:0}.container[_ngcontent-c0]   .row.custom-no-gutters[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:first-child{padding-left:0}.container[_ngcontent-c0]   .row.custom-no-gutters[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:last-child{padding-right:0}.container[_ngcontent-c0]   .row.custom-gutters[_ngcontent-c0]{margin-right:-15px;margin-left:-15px}.container[_ngcontent-c0]   .row.custom-gutters[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:first-child{padding-left:15px}.container[_ngcontent-c0]   .row.custom-gutters[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:last-child{padding-right:15px}@media (max-width:575.98px){.container[_ngcontent-c0]   .row.custom-gutters-sm[_ngcontent-c0]{margin-right:-15px;margin-left:-15px}.container[_ngcontent-c0]   .row.custom-gutters-sm[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:first-child{padding-left:15px}.container[_ngcontent-c0]   .row.custom-gutters-sm[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:last-child{padding-right:15px}.container[_ngcontent-c0]   .row.custom-no-gutters-sm[_ngcontent-c0]{margin-right:0;margin-left:0}.container[_ngcontent-c0]   .row.custom-no-gutters-sm[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:first-child{padding-left:0}.container[_ngcontent-c0]   .row.custom-no-gutters-sm[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:last-child{padding-right:0}}@media (max-width:767.98px){.container[_ngcontent-c0]   .row.custom-gutters-sm[_ngcontent-c0]{margin-right:-15px;margin-left:-15px}.container[_ngcontent-c0]   .row.custom-gutters-sm[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:first-child{padding-left:15px}.container[_ngcontent-c0]   .row.custom-gutters-sm[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:last-child{padding-right:15px}.container[_ngcontent-c0]   .row.custom-no-gutters-md[_ngcontent-c0]{margin-right:0;margin-left:0}.container[_ngcontent-c0]   .row.custom-no-gutters-md[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:first-child{padding-left:0}.container[_ngcontent-c0]   .row.custom-no-gutters-md[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:last-child{padding-right:0}}@media (max-width:991.98px){.container[_ngcontent-c0]   .row.custom-gutters-sm[_ngcontent-c0]{margin-right:-15px;margin-left:-15px}.container[_ngcontent-c0]   .row.custom-gutters-sm[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:first-child{padding-left:15px}.container[_ngcontent-c0]   .row.custom-gutters-sm[_ngcontent-c0] > [class^=col-][_ngcontent-c0]:last-child{padding-right:15px}.container[_ngcontent-c0]   .row.custom-no-gutters-lg[_ngcontent-c0]{margin-right:0;margin-left:0}.container[_ngcontent-c0]   .row.custom-no- ...
# <app-cart _nghost-c2="" class="ng-tns-c2-0 show-cartbar" id="mobile-cart"><!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# </app-cart>
# </div>
# <mat-drawer-container class="content mat-drawer-container" id="mat-content"><div class="mat-drawer-backdrop"></div><div class="cdk-visually-hidden cdk-focus-trap-anchor" tabindex="-1"></div><mat-drawer class="right-drawer mat-drawer ng-tns-c4-1 ng-trigger ng-trigger-transform mat-drawer-end mat-drawer-over ng-star-inserted" disableclose="true" id="right-drawer" mode="over" position="end" tabindex="-1">
# <!-- -->
# </mat-drawer><div class="cdk-visually-hidden cdk-focus-trap-anchor" tabindex="-1"></div><div class="cdk-visually-hidden cdk-focus-trap-anchor" tabindex="-1"></div><mat-drawer class="left-drawer mat-drawer ng-tns-c4-2 ng-trigger ng-trigger-transform mat-drawer-over ng-star-inserted" disableclose="true" id="left-drawer" mode="over" position="start" tabindex="-1">
# <app-drawer _nghost-c5=""><div _ngcontent-c5="" class="drawer-content">
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# </div>
# </app-drawer>
# </mat-drawer><div class="cdk-visually-hidden cdk-focus-trap-anchor" tabindex="-1"></div><mat-drawer-content cdk-scrollable="" class="wrapper mat-drawer-content" style="">
# <div class="app-header res-height">
# <app-header _nghost-c6=""><div _ngcontent-c6="" class="header-container">
# <!-- -->
# <div _ngcontent-c6="" class="d-none d-md-block ng-star-inserted" id="pre-header">
# <div _ngcontent-c6="" class="container">
# <div _ngcontent-c6="" class="row full-width">
# <div _ngcontent-c6="" class="col-12 col-md-3 col-lg-3 col-xl-3 p-1 font-weight-bold" id="doa">
# <span _ngcontent-c6="">Download Our App:</span>
# <span _ngcontent-c6="">
# <a _ngcontent-c6="" href="https://itunes.apple.com/in/app/tendercuts-farm-fresh-meat-and-fresh-fish/id1236186604?mt=8">
# <i _ngcontent-c6="" aria-hidden="true" class="fa fa-apple icon"></i>
# </a>
# </span>
# <span _ngcontent-c6="">
# <a _ngcontent-c6="" class="download-icon" href="https://play.google.com/store/apps/details?id=com.tendercuts.app" target="_blank">
# <i _ngcontent-c6="" aria-hidden="true" class="fa fa-android"></i>
# </a>
# </span>
# </div>
# <div _ngcontent-c6="" class="col-5 d-none d-md-flex justify-content-center align-items-center blogs">
# <a _ngcontent-c6="" class="page-scroll btn" href="/quality-check?agentname=supriya" queryparamshandling="merge">
# <span _ngcontent-c6="">Why TenderCuts</span>
# </a>
# <span _ngcontent-c6="" class="pipe">|</span>
# <a _ngcontent-c6="" class="page-scroll btn" href="https://blog.tendercuts.in/" target="_blank">
# <span _ngcontent-c6="">Blog</span>
# </a>
# <span _ngcontent-c6="" class="pipe">|</span>
# <a _ngcontent-c6="" class="btn" href="/franchisee?agentname=supriya" queryparamshandling="merge">
# <span _ngcontent-c6="">Franchise</span>
# </a>
# <span _ngcontent-c6="" class="pipe">|</span>
# <a _ngcontent-c6="" class="btn" href="/certification?agentname=supriya" queryparamshandling="merge">
# <span _ngcontent-c6="">Certificate</span>
# </a>
# <span _ngcontent-c6="" class="pipe">|</span>
# <a _ngcontent-c6="" class="btn" href="/store-address?agentname=supriya" queryparamshandling="merge">
# <span _ngcontent-c6="">Store Locator</span>
# </a>
# </div>
# <div _ngcontent-c6="" class="col-4 d-none d-md-flex p-1 justify-content-end font-weight-bold">
# <img _ngcontent-c6="" alt="120 mins Delivery" height="20" src="assets/delivery.png" width="35"/>
# <span _ngcontent-c6="">120 Minutes Delivery</span>
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# <div _ngcontent-c6="" class="row d-flex d-sm-flex d-md-none border-bottom address-header">
# <div _ngcontent-c6="" class="col-12 m-auto px-0 text-center border-right">
# <!-- -->
# <!-- -->
# <!-- -->
# </div>
# </div>
# <div _ngcontent-c6="" class="header d-none d-md-block d-lg-block d-xl-block">
# <div _ngcontent-c6="" class="container">
# <nav _ngcontent-c6="" class="row custom-gutters custom-no-gutters-sm">
# <div _ngcontent-c6="" class="col-7">
# <div _ngcontent-c6="" class="row no-gutters">
# <div _ngcontent-c6="" class="col-5 col-md-5 col-lg-4">
# <a _ngcontent-c6="" href="/home?agentname=supriya" queryparamshandling="merge">
# <img _ngcontent-c6="" alt="TenderCuts" class="img-logo img-responsive" src="assets/logo-white.png"/>
# </a>
# </div>
# <!-- -->
# <button _ngcontent-c6="" class="location-btn col-5 col-md-5 col-lg-4 ng-star-inserted" id="address-btn" mat-button=""><span class="mat-button-wrapper">
# <i _ngcontent-c6="" class="material-icons">location_on</i>
# <!-- --><span _ngcontent-c6="" class="text ng-star-inserted">
#                   THORAIPAKKAM STORE
#                 </span>
# <!-- -->
# </span><div class="mat-button-ripple mat-ripple" matripple=""></div><div class="mat-button-focus-overlay"></div></button>
# <!-- -->
# </div>
# </div>
# <!-- --><!-- -->
# <div _ngcontent-c6="" class="col-3 d-flex justify-content-end ng-star-inserted">
# <div _ngcontent-c6="" class="menu-container">
# <div _ngcontent-c6="" class="row custom-no-gutters">
# <button _ngcontent-c6="" id="login-button" mat-button=""><span class="mat-button-wrapper">
#                   Login / Sign Up
#                 </span><div class="mat-button-ripple mat-ripple" matripple=""></div><div class="mat-button-focus-overlay"></div></button>
# </div>
# </div>
# </div>
# <!-- -->
# <!-- -->
# </nav>
# </div>
# </div>
# <div _ngcontent-c6="" class="spacer d-none d-md-block d-lg-block d-xl-block"></div>
# <div _ngcontent-c6="" class="row d-flex d-sm-flex d-md-none mobile-header no-gutters">
# <!-- -->
# <div _ngcontent-c6="" class="m-auto col-10">
# <a _ngcontent-c6="" class="d-block text-center font-weight-bold" href="/home">
# <img _ngcontent-c6="" alt="" src="assets/logo-white.png"/>
# </a>
# </div>
# <!-- --><div _ngcontent-c6="" class="col-2 p-0 ng-star-inserted">
# <button _ngcontent-c6="" mat-icon-button=""><span class="mat-button-wrapper">
# <mat-icon _ngcontent-c6="" aria-hidden="true" class="mat-icon material-icons" role="img">account_circle</mat-icon>
# </span><div class="mat-button-ripple mat-ripple" matripple=""></div><div class="mat-button-focus-overlay"></div></button>
# </div>
# <!-- -->
# </div>
# </div>
# </app-header>
# </div>
# <div class="routing-container">
# <router-outlet></router-outlet><app-category _nghost-c38="" class="ng-star-inserted"><app-category-bar _ngcontent-c38=""><!-- --><!-- -->
# <!-- -->
# <div class="category-bar ng-star-inserted">
# <!-- --><div class="tile-mode align-items-center ng-star-inserted">
# <!-- --><!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 active ng-star-inserted" id="tile-cat-38">
# <span class="cat-name">
# <img alt="Dry Fish" class="thumb-image" src="https://assets.tendercuts.in/category/38.png"/>
#             Dry Fish
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-30">
# <span class="cat-name">
# <img alt="Combo" class="thumb-image" src="https://assets.tendercuts.in/category/30.png"/>
#             Combo
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-4">
# <span class="cat-name">
# <img alt="Chicken" class="thumb-image" src="https://assets.tendercuts.in/category/4.png"/>
#             Chicken
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-5">
# <span class="cat-name">
# <img alt="Mutton" class="thumb-image" src="https://assets.tendercuts.in/category/5.png"/>
#             Mutton
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-14">
# <span class="cat-name">
# <img alt="Sea Food" class="thumb-image" src="https://assets.tendercuts.in/category/14.png"/>
#             Sea Food
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-15">
# <span class="cat-name">
# <img alt="Ready To Cook" class="thumb-image" src="https://assets.tendercuts.in/category/15.png"/>
#             Ready To Cook
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-24">
# <span class="cat-name">
# <img alt="Cold Cuts" class="thumb-image" src="https://assets.tendercuts.in/category/24.png"/>
#             Cold Cuts
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-18">
# <span class="cat-name">
# <img alt="Eggs" class="thumb-image" src="https://assets.tendercuts.in/category/18.png"/>
#             Eggs
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-22">
# <span class="cat-name">
# <img alt="Pickles" class="thumb-image" src="https://assets.tendercuts.in/category/22.png"/>
#             Pickles
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-23">
# <span class="cat-name">
# <img alt="Spices" class="thumb-image" src="https://assets.tendercuts.in/category/23.png"/>
#             Spices
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-28">
# <span class="cat-name">
# <img alt="Party Pack" class="thumb-image" src="https://assets.tendercuts.in/category/28.png"/>
#             Party Pack
#           </span>
# </div>
# <!-- -->
# <div class="transition cat-display d-flex align-items-center justify-content-center h-100 ng-star-inserted" id="tile-cat-42">
# <span class="cat-name">
# <img alt="Oils" class="thumb-image" src="https://assets.tendercuts.in/category/42.png"/>
#             Oils
#           </span>
# </div>
# </div>
# </div>
# <!-- -->
# <!-- -->
# </app-category-bar>
# <app-category-display _ngcontent-c38="" _nghost-c32=""><div _ngcontent-c32="" class="category-display container full-width">
# <!-- -->
# <!-- --><div _ngcontent-c32="" class="ng-star-inserted">
# <app-category-title _ngcontent-c32="" _nghost-c33=""><div _ngcontent-c33="" class="category-title">
# <h3 _ngcontent-c33="">Dry Fish</h3>
# </div>
# </app-category-title>
# <div _ngcontent-c32="" class="row">
# <!-- --><div _ngcontent-c32="" class="col-sm-12 col-md-6 col-lg-4 col-xl-4 product-tile ng-star-inserted">
# <app-product _ngcontent-c32="" class="products ng-tns-c9-3"><div class="product-display compact-mode" id="product-985">
# <!-- --><mat-card class="mat-card ng-tns-c9-3 ng-trigger ng-trigger-zoomIn ng-star-inserted">
# <div class="ng-tns-c9-3">
# <div class="product-image">
# <!-- -->
# <app-lazy-load _nghost-c24="" class="ng-tns-c9-3"><div _ngcontent-c24="" class="app-lazy-load">
# <!-- -->
# </div>
# </app-lazy-load>
# <!-- -->
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-3"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-3">Dry Seer Fish</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-3">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <!-- --><mat-card-content class="mat-card-content ng-tns-c9-3 ng-star-inserted" style="">
# <!-- -->
# <div class="row weight ng-tns-c9-3 ng-star-inserted">
# <div class="col-8">
# <div class="row">
# <span aria-haspopup="true" class="callout">
# <span class="weight-icon">
# <img alt="Weight" class="ng-tns-c9-3" src="assets/images/weight.png"/>
# </span>
# <span class="ng-tns-c9-3"> Weight:</span>  1 Pack</span>
# <mat-menu class="" xposition="before"><!-- --></mat-menu>
# </div>
# </div>
# <div class="col-4">
# <!-- -->
# </div>
# </div>
# <!-- -->
# </mat-card-content>
# <!-- -->
# <mat-card-actions class="mat-card-actions ng-tns-c9-3">
# <div class="row d-flex align-items-center justify-content-center">
# <div class="col-7">
# <app-price-display _nghost-c36="" class="ng-tns-c9-3">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹120
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# </div>
# <div class="col-5">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-3"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </div>
# </mat-card-actions>
# </mat-card>
# <!-- -->
# <!-- -->
# <!-- -->
# <mat-card class="d-none mat-card ng-trigger ng-trigger-zoomIn">
# <div class="ng-tns-c9-3">
# <div class="product-image">
# <img alt="Item thumb" class="mat-card-image" mat-card-image="" src="https://assets.tendercuts.in/product/d/r/dry_seer_fish.jpg"/>
# <div class="placeholder-img"></div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-3"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-3">Dry Seer Fish</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-3">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <mat-card-actions class="mat-card-actions ng-tns-c9-3">
# <app-price-display _nghost-c36="" class="ng-tns-c9-3">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹120
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# <div class="row no-gutters">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-3"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </mat-card-actions>
# </mat-card>
# </div>
# </app-product>
# </div><div _ngcontent-c32="" class="col-sm-12 col-md-6 col-lg-4 col-xl-4 product-tile ng-star-inserted">
# <app-product _ngcontent-c32="" class="products ng-tns-c9-4"><div class="product-display compact-mode" id="product-981">
# <!-- --><mat-card class="mat-card ng-tns-c9-4 ng-trigger ng-trigger-zoomIn ng-star-inserted">
# <div class="ng-tns-c9-4">
# <div class="product-image">
# <!-- -->
# <app-lazy-load _nghost-c24="" class="ng-tns-c9-4"><div _ngcontent-c24="" class="app-lazy-load">
# <!-- -->
# </div>
# </app-lazy-load>
# <!-- -->
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-4"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-4">Dry Ribbon Fish</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-4">Net Weight: 100Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <!-- --><mat-card-content class="mat-card-content ng-tns-c9-4 ng-star-inserted" style="">
# <!-- -->
# <div class="row weight ng-tns-c9-4 ng-star-inserted">
# <div class="col-8">
# <div class="row">
# <span aria-haspopup="true" class="callout">
# <span class="weight-icon">
# <img alt="Weight" class="ng-tns-c9-4" src="assets/images/weight.png"/>
# </span>
# <span class="ng-tns-c9-4"> Weight:</span>  1 Pack</span>
# <mat-menu class="" xposition="before"><!-- --></mat-menu>
# </div>
# </div>
# <div class="col-4">
# <!-- -->
# </div>
# </div>
# <!-- -->
# </mat-card-content>
# <!-- -->
# <mat-card-actions class="mat-card-actions ng-tns-c9-4">
# <div class="row d-flex align-items-center justify-content-center">
# <div class="col-7">
# <app-price-display _nghost-c36="" class="ng-tns-c9-4">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹60
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# </div>
# <div class="col-5">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-4"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </div>
# </mat-card-actions>
# </mat-card>
# <!-- -->
# <!-- -->
# <!-- -->
# <mat-card class="d-none mat-card ng-trigger ng-trigger-zoomIn">
# <div class="ng-tns-c9-4">
# <div class="product-image">
# <img alt="Item thumb" class="mat-card-image" mat-card-image="" src="https://assets.tendercuts.in/product/d/r/dry_ribbon_fish.jpg"/>
# <div class="placeholder-img"></div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-4"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-4">Dry Ribbon Fish</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-4">Net Weight: 100Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <mat-card-actions class="mat-card-actions ng-tns-c9-4">
# <app-price-display _nghost-c36="" class="ng-tns-c9-4">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹60
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# <div class="row no-gutters">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-4"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </mat-card-actions>
# </mat-card>
# </div>
# </app-product>
# </div><div _ngcontent-c32="" class="col-sm-12 col-md-6 col-lg-4 col-xl-4 product-tile ng-star-inserted">
# <app-product _ngcontent-c32="" class="products ng-tns-c9-5"><div class="product-display compact-mode" id="product-983">
# <!-- --><mat-card class="mat-card ng-tns-c9-5 ng-trigger ng-trigger-zoomIn ng-star-inserted">
# <div class="ng-tns-c9-5">
# <div class="product-image">
# <!-- -->
# <app-lazy-load _nghost-c24="" class="ng-tns-c9-5"><div _ngcontent-c24="" class="app-lazy-load">
# <!-- -->
# </div>
# </app-lazy-load>
# <!-- -->
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-5"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-5">Dry Nethili Fish ( Big Anchovies )</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-5">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <!-- --><mat-card-content class="mat-card-content ng-tns-c9-5 ng-star-inserted" style="">
# <!-- -->
# <div class="row weight ng-tns-c9-5 ng-star-inserted">
# <div class="col-8">
# <div class="row">
# <span aria-haspopup="true" class="callout">
# <span class="weight-icon">
# <img alt="Weight" class="ng-tns-c9-5" src="assets/images/weight.png"/>
# </span>
# <span class="ng-tns-c9-5"> Weight:</span>  1 Pack</span>
# <mat-menu class="" xposition="before"><!-- --></mat-menu>
# </div>
# </div>
# <div class="col-4">
# <!-- -->
# </div>
# </div>
# <!-- -->
# </mat-card-content>
# <!-- -->
# <mat-card-actions class="mat-card-actions ng-tns-c9-5">
# <div class="row d-flex align-items-center justify-content-center">
# <div class="col-7">
# <app-price-display _nghost-c36="" class="ng-tns-c9-5">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹120
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# </div>
# <div class="col-5">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-5"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </div>
# </mat-card-actions>
# </mat-card>
# <!-- -->
# <!-- -->
# <!-- -->
# <mat-card class="d-none mat-card ng-trigger ng-trigger-zoomIn">
# <div class="ng-tns-c9-5">
# <div class="product-image">
# <img alt="Item thumb" class="mat-card-image" mat-card-image="" src="https://assets.tendercuts.in/product/d/r/dry_big_nethili_fish.jpg"/>
# <div class="placeholder-img"></div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-5"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-5">Dry Nethili Fish ( Big Anchovies )</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-5">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <mat-card-actions class="mat-card-actions ng-tns-c9-5">
# <app-price-display _nghost-c36="" class="ng-tns-c9-5">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹120
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# <div class="row no-gutters">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-5"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </mat-card-actions>
# </mat-card>
# </div>
# </app-product>
# </div><div _ngcontent-c32="" class="col-sm-12 col-md-6 col-lg-4 col-xl-4 product-tile ng-star-inserted">
# <app-product _ngcontent-c32="" class="products ng-tns-c9-6"><div class="product-display compact-mode" id="product-987">
# <!-- --><mat-card class="mat-card ng-tns-c9-6 ng-trigger ng-trigger-zoomIn ng-star-inserted">
# <div class="ng-tns-c9-6">
# <div class="product-image">
# <!-- -->
# <app-lazy-load _nghost-c24="" class="ng-tns-c9-6"><div _ngcontent-c24="" class="app-lazy-load">
# <!-- -->
# </div>
# </app-lazy-load>
# <!-- -->
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-6"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-6">Dry Sole Fish</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-6">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <!-- --><mat-card-content class="mat-card-content ng-tns-c9-6 ng-star-inserted" style="">
# <!-- -->
# <div class="row weight ng-tns-c9-6 ng-star-inserted">
# <div class="col-8">
# <div class="row">
# <span aria-haspopup="true" class="callout">
# <span class="weight-icon">
# <img alt="Weight" class="ng-tns-c9-6" src="assets/images/weight.png"/>
# </span>
# <span class="ng-tns-c9-6"> Weight:</span>  1 Pack</span>
# <mat-menu class="" xposition="before"><!-- --></mat-menu>
# </div>
# </div>
# <div class="col-4">
# <!-- -->
# </div>
# </div>
# <!-- -->
# </mat-card-content>
# <!-- -->
# <mat-card-actions class="mat-card-actions ng-tns-c9-6">
# <div class="row d-flex align-items-center justify-content-center">
# <div class="col-7">
# <app-price-display _nghost-c36="" class="ng-tns-c9-6">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹50
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# </div>
# <div class="col-5">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-6"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </div>
# </mat-card-actions>
# </mat-card>
# <!-- -->
# <!-- -->
# <!-- -->
# <mat-card class="d-none mat-card ng-trigger ng-trigger-zoomIn">
# <div class="ng-tns-c9-6">
# <div class="product-image">
# <img alt="Item thumb" class="mat-card-image" mat-card-image="" src="https://assets.tendercuts.in/product/d/r/dry_sole_fish.jpg"/>
# <div class="placeholder-img"></div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-6"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-6">Dry Sole Fish</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-6">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <mat-card-actions class="mat-card-actions ng-tns-c9-6">
# <app-price-display _nghost-c36="" class="ng-tns-c9-6">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹50
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# <div class="row no-gutters">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-6"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </mat-card-actions>
# </mat-card>
# </div>
# </app-product>
# </div><div _ngcontent-c32="" class="col-sm-12 col-md-6 col-lg-4 col-xl-4 product-tile ng-star-inserted">
# <app-product _ngcontent-c32="" class="products ng-tns-c9-7"><div class="product-display compact-mode" id="product-989">
# <!-- --><mat-card class="mat-card ng-tns-c9-7 ng-trigger ng-trigger-zoomIn ng-star-inserted">
# <div class="ng-tns-c9-7">
# <div class="product-image">
# <!-- -->
# <app-lazy-load _nghost-c24="" class="ng-tns-c9-7"><div _ngcontent-c24="" class="app-lazy-load">
# <!-- -->
# </div>
# </app-lazy-load>
# <!-- -->
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-7"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-7">Dry Shark Fish</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-7">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <!-- --><mat-card-content class="mat-card-content ng-tns-c9-7 ng-star-inserted" style="">
# <!-- -->
# <div class="row weight ng-tns-c9-7 ng-star-inserted">
# <div class="col-8">
# <div class="row">
# <span aria-haspopup="true" class="callout">
# <span class="weight-icon">
# <img alt="Weight" class="ng-tns-c9-7" src="assets/images/weight.png"/>
# </span>
# <span class="ng-tns-c9-7"> Weight:</span>  1 Pack</span>
# <mat-menu class="" xposition="before"><!-- --></mat-menu>
# </div>
# </div>
# <div class="col-4">
# <!-- -->
# </div>
# </div>
# <!-- -->
# </mat-card-content>
# <!-- -->
# <mat-card-actions class="mat-card-actions ng-tns-c9-7">
# <div class="row d-flex align-items-center justify-content-center">
# <div class="col-7">
# <app-price-display _nghost-c36="" class="ng-tns-c9-7">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹70
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# </div>
# <div class="col-5">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-7"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </div>
# </mat-card-actions>
# </mat-card>
# <!-- -->
# <!-- -->
# <!-- -->
# <mat-card class="d-none mat-card ng-trigger ng-trigger-zoomIn">
# <div class="ng-tns-c9-7">
# <div class="product-image">
# <img alt="Item thumb" class="mat-card-image" mat-card-image="" src="https://assets.tendercuts.in/product/d/r/dry_shark_fish.jpg"/>
# <div class="placeholder-img"></div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-7"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-7">Dry Shark Fish</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-7">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <mat-card-actions class="mat-card-actions ng-tns-c9-7">
# <app-price-display _nghost-c36="" class="ng-tns-c9-7">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹70
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# <div class="row no-gutters">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-7"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </mat-card-actions>
# </mat-card>
# </div>
# </app-product>
# </div><div _ngcontent-c32="" class="col-sm-12 col-md-6 col-lg-4 col-xl-4 product-tile ng-star-inserted">
# <app-product _ngcontent-c32="" class="products ng-tns-c9-8"><div class="product-display compact-mode" id="product-991">
# <!-- --><mat-card class="mat-card ng-tns-c9-8 ng-trigger ng-trigger-zoomIn ng-star-inserted">
# <div class="ng-tns-c9-8">
# <div class="product-image">
# <!-- -->
# <app-lazy-load _nghost-c24="" class="ng-tns-c9-8"><div _ngcontent-c24="" class="app-lazy-load">
# <!-- -->
# </div>
# </app-lazy-load>
# <!-- -->
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-8"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-8">Dry Nethili Fish ( Small Anchovies )</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-8">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <!-- --><mat-card-content class="mat-card-content ng-tns-c9-8 ng-star-inserted" style="">
# <!-- -->
# <div class="row weight ng-tns-c9-8 ng-star-inserted">
# <div class="col-8">
# <div class="row">
# <span aria-haspopup="true" class="callout">
# <span class="weight-icon">
# <img alt="Weight" class="ng-tns-c9-8" src="assets/images/weight.png"/>
# </span>
# <span class="ng-tns-c9-8"> Weight:</span>  1 Pack</span>
# <mat-menu class="" xposition="before"><!-- --></mat-menu>
# </div>
# </div>
# <div class="col-4">
# <!-- -->
# </div>
# </div>
# <!-- -->
# </mat-card-content>
# <!-- -->
# <mat-card-actions class="mat-card-actions ng-tns-c9-8">
# <div class="row d-flex align-items-center justify-content-center">
# <div class="col-7">
# <app-price-display _nghost-c36="" class="ng-tns-c9-8">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹60
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# </div>
# <div class="col-5">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-8"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </div>
# </mat-card-actions>
# </mat-card>
# <!-- -->
# <!-- -->
# <!-- -->
# <mat-card class="d-none mat-card ng-trigger ng-trigger-zoomIn">
# <div class="ng-tns-c9-8">
# <div class="product-image">
# <img alt="Item thumb" class="mat-card-image" mat-card-image="" src="https://assets.tendercuts.in/product/d/r/dry_nethili_fish.jpg"/>
# <div class="placeholder-img"></div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-8"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-8">Dry Nethili Fish ( Small Anchovies )</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-8">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <mat-card-actions class="mat-card-actions ng-tns-c9-8">
# <app-price-display _nghost-c36="" class="ng-tns-c9-8">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹60
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# <div class="row no-gutters">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-8"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </mat-card-actions>
# </mat-card>
# </div>
# </app-product>
# </div><div _ngcontent-c32="" class="col-sm-12 col-md-6 col-lg-4 col-xl-4 product-tile ng-star-inserted">
# <app-product _ngcontent-c32="" class="products ng-tns-c9-9"><div class="product-display compact-mode" id="product-993">
# <!-- --><mat-card class="mat-card ng-tns-c9-9 ng-trigger ng-trigger-zoomIn ng-star-inserted">
# <div class="ng-tns-c9-9">
# <div class="product-image">
# <!-- -->
# <app-lazy-load _nghost-c24="" class="ng-tns-c9-9"><div _ngcontent-c24="" class="app-lazy-load">
# <!-- -->
# </div>
# </app-lazy-load>
# <!-- -->
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-9"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-9">Dry Prawns ( 80g )</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-9">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <!-- --><mat-card-content class="mat-card-content ng-tns-c9-9 ng-star-inserted" style="">
# <!-- -->
# <div class="row weight ng-tns-c9-9 ng-star-inserted">
# <div class="col-8">
# <div class="row">
# <span aria-haspopup="true" class="callout">
# <span class="weight-icon">
# <img alt="Weight" class="ng-tns-c9-9" src="assets/images/weight.png"/>
# </span>
# <span class="ng-tns-c9-9"> Weight:</span>  1 Pack</span>
# <mat-menu class="" xposition="before"><!-- --></mat-menu>
# </div>
# </div>
# <div class="col-4">
# <!-- -->
# </div>
# </div>
# <!-- -->
# </mat-card-content>
# <!-- -->
# <mat-card-actions class="mat-card-actions ng-tns-c9-9">
# <div class="row d-flex align-items-center justify-content-center">
# <div class="col-7">
# <app-price-display _nghost-c36="" class="ng-tns-c9-9">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹75
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# </div>
# <div class="col-5">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-9"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </div>
# </mat-card-actions>
# </mat-card>
# <!-- -->
# <!-- -->
# <!-- -->
# <mat-card class="d-none mat-card ng-trigger ng-trigger-zoomIn">
# <div class="ng-tns-c9-9">
# <div class="product-image">
# <img alt="Item thumb" class="mat-card-image" mat-card-image="" src="https://assets.tendercuts.in/product/d/r/dry_prawns.jpg"/>
# <div class="placeholder-img"></div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# <mat-card-header class="mat-card-header ng-tns-c9-9"><div class="mat-card-header-text"><mat-card-title class="mat-card-title ng-tns-c9-9">Dry Prawns ( 80g )</mat-card-title><mat-card-subtitle class="mat-card-subtitle ng-tns-c9-9">Net Weight: 80Gms - From H.S. Dry Fish</mat-card-subtitle></div>
# </mat-card-header>
# <mat-card-actions class="mat-card-actions ng-tns-c9-9">
# <app-price-display _nghost-c36="" class="ng-tns-c9-9">
# <!-- -->
# <div _ngcontent-c36="" class="row no-gutters text-center ng-star-inserted" style="">
# <p _ngcontent-c36="" class="current-price bold price" style="font-size:1.2rem;">
# <!-- -->
#       ₹75
#     </p>
# </div>
# <!-- -->
# </app-price-display>
# <div class="row no-gutters">
# <app-add-to-cart _nghost-c37="" apppreventeventpropogation="" class="ng-tns-c9-9"><!-- -->
# <!-- -->
# <!-- -->
# </app-add-to-cart>
# </div>
# </mat-card-actions>
# </mat-card>
# </div>
# </app-product>
# </div>
# </div>
# </div>
# <!-- -->
# </div>
# </app-category-display>
# </app-category>
# </div>
# <app-footer _nghost-c7="">
# <div _ngcontent-c7="" class="footer-wrapper">
# <mat-card _ngcontent-c7="" class="press full-width mat-card">
# <mat-card-content _ngcontent-c7="" class="mat-card-content">
# <h3 _ngcontent-c7="">"A dose of kindness on your plate"</h3>
# <div _ngcontent-c7="" class="row press justify-content-center">
# <!-- --><a _ngcontent-c7="" class="col-12 col-sm-6 col-md-4 col-lg-2 col-xl-2 post ng-star-inserted" href="https://www.thehindu.com/life-and-style/food/a-dose-of-kindness-on-your-plate/article17433445.ece" id="post-0" style="opacity:1;" target="_blank">
# <app-lazy-load _ngcontent-c7="" _nghost-c24=""><div _ngcontent-c24="" class="app-lazy-load">
# <!-- -->
# </div>
# </app-lazy-load>
# </a><a _ngcontent-c7="" class="col-12 col-sm-6 col-md-4 col-lg-2 col-xl-2 post ng-star-inserted" href="https://timesofindia.indiatimes.com/companies/farm-fresh-fare-startup/articleshow/55936559.cms" id="post-1" style="opacity:0.3;" target="_blank">
# <app-lazy-load _ngcontent-c7="" _nghost-c24=""><div _ngcontent-c24="" class="app-lazy-load">
# <!-- -->
# </div>
# </app-lazy-load>
# </a><a _ngcontent-c7="" class="col-12 col-sm-6 col-md-4 col-lg-2 col-xl-2 post ng-star-inserted" href="https://yourstory.com/2017/05/tendercuts-startup/" id="post-2" style="opacity:0.3;" target="_blank">
# <app-lazy-load _ngcontent-c7="" _nghost-c24=""><div _ngcontent-c24="" class="app-lazy-load">
# <!-- -->
# </div>
# </app-lazy-load>
# </a>
# </div>
# </mat-card-content>
# </mat-card>
# </div>
# <div _ngcontent-c7="" class="footer-wrapper">
# <mat-card _ngcontent-c7="" class="mat-card full-width mat-card">
# <div _ngcontent-c7="" class="row">
# <div _ngcontent-c7="" class="col-12 col-sm-6 col-md-4 col-lg-3 col-xl-3 company">
# <!-- --><mat-list _ngcontent-c7="" class="mat-list ng-star-inserted">
# <mat-list-item _ngcontent-c7="" class="list-header mat-list-item"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
#             COMPANY
#           </div></mat-list-item>
# <!-- --><mat-list-item _ngcontent-c7="" class="footerbuttons p-0 mat-list-item ng-star-inserted"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
#             Privacy Policy
#           </div></mat-list-item><mat-list-item _ngcontent-c7="" class="footerbuttons p-0 mat-list-item ng-star-inserted"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
#             Terms and Condition
#           </div></mat-list-item>
# <mat-list-item _ngcontent-c7="" class="mat-list-item"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
#             FAQ
#           </div></mat-list-item>
# </mat-list>
# </div>
# <div _ngcontent-c7="" class="col-12 col-sm-6 col-md-4 col-lg-3 col-xl-3 social">
# <mat-list _ngcontent-c7="" class="mat-list">
# <mat-list-item _ngcontent-c7="" class="list-header mat-list-item"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
#             STAY CONNECTED
#           </div></mat-list-item>
# <mat-list-item _ngcontent-c7="" class="mat-list-item"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
# <div _ngcontent-c7="" class="row no-gutters">
# <i _ngcontent-c7="" aria-hidden="true" class="fa fa-envelope-open col-1"></i>
# <span _ngcontent-c7="" class="col-11">
# <a _ngcontent-c7="" class="footerbuttons" href="mailto:cs@tendercuts.in">
#                   cs@tendercuts.in
#                 </a>
# </span>
# </div>
# </div></mat-list-item>
# <mat-list-item _ngcontent-c7="" class="mat-list-item"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
# <div _ngcontent-c7="" class="row no-gutters">
# <i _ngcontent-c7="" aria-hidden="true" class="fa fa-phone col-1"></i>
# <span _ngcontent-c7="" class="col-11">Chennai - 9543754375</span>
# </div>
# </div></mat-list-item>
# <mat-list-item _ngcontent-c7="" class="mat-list-item"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
# <div _ngcontent-c7="" class="row no-gutters">
# <i _ngcontent-c7="" aria-hidden="true" class="fa fa-phone col-1"></i>
# <span _ngcontent-c7="" class="col-11">Hyderabad - 8282888855</span>
# </div>
# </div></mat-list-item>
# <mat-list-item _ngcontent-c7="" class="mat-list-item"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
# <div _ngcontent-c7="" class="row no-gutters">
# <i _ngcontent-c7="" aria-hidden="true" class="fa fa-facebook col-1"></i>
# <span _ngcontent-c7="" class="col-11">
# <a _ngcontent-c7="" class="footerbuttons" href="https://www.facebook.com/pg/TenderCutsIN/about/" target="_blank">
#                   Facebook
#                 </a>
# </span>
# </div>
# </div></mat-list-item>
# <mat-list-item _ngcontent-c7="" class="footerbuttons mat-list-item" queryparamshandling="merge" tabindex="0"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
# <div _ngcontent-c7="" class="row no-gutters">
# <i _ngcontent-c7="" aria-hidden="true" class="fa fa-file-text-o col-1"></i>
# <span _ngcontent-c7="" class="col-11">
#                     Contact Us
#               </span>
# </div>
# </div></mat-list-item>
# </mat-list>
# </div>
# <div _ngcontent-c7="" class="col-12 col-sm-6 col-md-4 col-lg-3 col-xl-3 links">
# <mat-list _ngcontent-c7="" class="mat-list">
# <mat-list-item _ngcontent-c7="" class="list-header mat-list-item"><div class="mat-list-item-content"><div class="mat-list-item-ripple mat-ripple" mat-ripple=""></div><div class="mat-list-text"></div>
#             LINKS
#           </div></mat-list-item>
# ...
# <div _ngcontent-c7="" class="container py-3 popular-cateogry ng-star-inserted">
# <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#             MUTTON
#           </p>
# <div _ngcontent-c7="" class="row py-1">
# <!-- --><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/free-range-goat-curry-cut?agentname=supriya" queryparamshandling="merge">
#               Premium Goat Curry Cut (Low Fat)
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/regualr-goat-curry-cut?agentname=supriya" queryparamshandling="merge">
#               Regular Goat Curry Cut
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/free-range-goat-biryani-cut?agentname=supriya" queryparamshandling="merge">
#               Free Range Goat Biryani Cut
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/party-pack-mutton-curry-cut?agentname=supriya" queryparamshandling="merge">
#               Premium Goat Curry Cut [1 KG]
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/free-range-goat-mince?agentname=supriya" queryparamshandling="merge">
#               Free Range Mutton Mince
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/free-range-goat-boneless?agentname=supriya" queryparamshandling="merge">
#               Free Range Mutton Boneless
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/free-range-goat-shoulder-meat?agentname=supriya" queryparamshandling="merge">
#               Free Range Mutton Shoulder Meat
#             </a>
# </div>
# </div>
# </div><div _ngcontent-c7="" class="ng-star-inserted">
# <!-- --><!-- -->
# <div _ngcontent-c7="" class="container py-3 popular-cateogry ng-star-inserted">
# <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#             SEA FOOD
#           </p>
# <div _ngcontent-c7="" class="row py-1">
# <!-- --><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/prawn-eral-seafood?agentname=supriya" queryparamshandling="merge">
#               Prawns Medium - Deshelled
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/prawn-eral-deshelled-small?agentname=supriya" queryparamshandling="merge">
#               Prawns Small - Deshelled
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/party-pack-prawn-medium?agentname=supriya" queryparamshandling="merge">
#               Prawns Medium - Deshelled [1 KG]
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/snapper-sankara-medium?agentname=supriya" queryparamshandling="merge">
#               Snapper/ Sankara - Medium
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/black-pomfret-vawaal-fish?agentname=supriya" queryparamshandling="merge">
#               Black Pomfert /Karuppu Vavval
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/indian-oil-sardine-mathi?agentname=supriya" queryparamshandling="merge">
#               Sardine - Mathi/Kavalai
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/catla-bengal-fish?agentname=supriya" queryparamshandling="merge">
#               Catla Large (800 Gms to 1.2 Kg)
#             </a>
# </div>
# </div>
# </div><div _ngcontent-c7="" class="ng-star-inserted">
# <!-- --><!-- -->
# <div _ngcontent-c7="" class="container py-3 popular-cateogry ng-star-inserted">
# <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#             READY TO COOK
#           </p>
# <div _ngcontent-c7="" class="row py-1">
# <!-- --><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/frozen-spicy-chicken-grill-patty?agentname=supriya" queryparamshandling="merge">
#               Spicy Chicken Grill Patty
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/karuveppilai-chicken?agentname=supriya" queryparamshandling="merge">
#               Karuveppilai Chicken
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/frozen-chicken-pop-corn?agentname=supriya" queryparamshandling="merge">
#               Chicken Pop Corn
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/chilli-garlic-prawns?agentname=supriya" queryparamshandling="merge">
#               Chilli Garlic Prawns
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/chettinad-prawns-65?agentname=supriya" queryparamshandling="merge">
#               Chettinad Prawns 65
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/garlic-chilli-wings?agentname=supriya" queryparamshandling="merge">
#               Garlic Chilli Wings
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/pepper-chicken?agentname=supriya" queryparamshandling="merge">
#               Pepper Chicken
#             </a>
# </div>
# </div>
# </div><div _ngcontent-c7="" class="ng-star-inserted">
# <!-- --><!-- -->
# <div _ngcontent-c7="" class="container py-3 popular-cateogry ng-star-inserted">
# <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#             COLD CUTS
#           </p>
# <div _ngcontent-c7="" class="row py-1">
# <!-- --><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/chicken-vindaloo?agentname=supriya" queryparamshandling="merge">
#               Chicken Vindaloo
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/chicken-xacuti?agentname=supriya" queryparamshandling="merge">
#               Chicken Xacuti
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/chicken-tikka?agentname=supriya" queryparamshandling="merge">
#               Chicken Tikka
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/butter-chicken?agentname=supriya" queryparamshandling="merge">
#               Butter Chicken
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/kadai-chicken?agentname=supriya" queryparamshandling="merge">
#               Kadai Chicken
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/german-style-chicken-nuremberger-sausage?agentname=supriya" queryparamshandling="merge">
#               Chicken Nuremberger Sausage
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/german-style-chicken-krakauer-smoked?agentname=supriya" queryparamshandling="merge">
#               Chicken Breakfast Sausage
#             </a>
# </div>
# </div>
# </div><div _ngcontent-c7="" class="ng-star-inserted">
# <!-- --><!-- -->
# <div _ngcontent-c7="" class="container py-3 popular-cateogry ng-star-inserted">
# <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#             EGGS
#           </p>
# <div _ngcontent-c7="" class="row py-1">
# <!-- --><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/upf-healthy-eggs-daily-6-pcs?agentname=supriya" queryparamshandling="merge">
#               UPF Healthy Eggs Daily 6 Pcs
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/upf-healthy-eggs-brown-6-pcs?agentname=supriya" queryparamshandling="merge">
#               UPF Healthy Eggs Brown 6 Pcs
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/farm-made-free-range-6-pcs?agentname=supriya" queryparamshandling="merge">
#               Farm Made Free Range 6 Pcs
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/egg?agentname=supriya" queryparamshandling="merge">
#               Dozen White Eggs - Pack of  6
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/country-egg?agentname=supriya" queryparamshandling="merge">
#               Country Chicken Eggs - Pack of  6
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/quail-eggs?agentname=supriya" queryparamshandling="merge">
#               Quail Eggs - Pack of 12
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/skm-best-fresh-eggs-pack-of-6?agentname=supriya" queryparamshandling="merge">
#               SKM Best Fresh Eggs - Pack of 6
#             </a>
# </div>
# </div>
# </div><div _ngcontent-c7="" class="ng-star-inserted">
# <!-- --><!-- -->
# <div _ngcontent-c7="" class="container py-3 popular-cateogry ng-star-inserted">
# <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#             PICKLES
#           </p>
# <div _ngcontent-c7="" class="row py-1">
# <!-- --><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/guntur-chicken-pickle?agentname=supriya" queryparamshandling="merge">
#               Guntur Chicken Pickle
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/guntur-mutton-pickle?agentname=supriya" queryparamshandling="merge">
#               Guntur Mutton Pickle
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/guntur-prawn-pickle?agentname=supriya" queryparamshandling="merge">
#               Guntur Prawn Pickle
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/guntur-fish-pickle?agentname=supriya" queryparamshandling="merge">
#               Guntur Fish Pickle
#             </a>
# </div>
# </div>
# </div><div _ngcontent-c7="" class="ng-star-inserted">
# <!-- --><!-- -->
# <div _ngcontent-c7="" class="container py-3 popular-cateogry ng-star-inserted">
# <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#             SPICES
#           </p>
# <div _ngcontent-c7="" class="row py-1">
# <!-- --><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/easy-chicken-65-mix?agentname=supriya" queryparamshandling="merge">
#               Easy Chicken 65 Mix
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/coriander-powder?agentname=supriya" queryparamshandling="merge">
#               Coriander Powder
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/madras-fish-masala?agentname=supriya" queryparamshandling="merge">
#               Madras Fish Masala
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/easy-marina-fish-roast-mix?agentname=supriya" queryparamshandling="merge">
#               Easy Marina fish Roast Mix
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/garam-masala?agentname=supriya" queryparamshandling="merge">
#               Garam Masala
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/easy-biryani-masala?agentname=supriya" queryparamshandling="merge">
#               Easy Biryani Masala
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/chilli-powder?agentname=supriya" queryparamshandling="merge">
#               Chilli Powder
#             </a>
# </div>
# </div>
# </div><div _ngcontent-c7="" class="ng-star-inserted">
# <!-- --><!-- -->
# <div _ngcontent-c7="" class="container py-3 popular-cateogry ng-star-inserted">
# <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#             PARTY PACK
#           </p>
# <div _ngcontent-c7="" class="row py-1">
# <!-- --><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/party-pack-small-chicken-curry-cut?agentname=supriya" queryparamshandling="merge">
#               Chicken Curry Cut (Skin Off) - 2 KG
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/party-pack-chicken-boneless-cubes?agentname=supriya" queryparamshandling="merge">
#               Chicken Boneless (Cubes) (1 Kg)
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/party-pack-mutton-curry-cut?agentname=supriya" queryparamshandling="merge">
#               Premium Goat Curry Cut [1 KG]
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/party-pack-medium-chicken-curry-cut?agentname=supriya" queryparamshandling="merge">
#               Chicken Curry Cut (Skin Off) - 3 KG
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/party-pack-prawn-medium?agentname=supriya" queryparamshandling="merge">
#               Prawns Medium - Deshelled [1 KG]
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/party-pack-madras-chicken-65-with-bone?agentname=supriya" queryparamshandling="merge">
#               Madras Chicken 65 ( With Bone) (1 Kg)
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/party-pack-madras-chicken-65-boneless?agentname=supriya" queryparamshandling="merge">
#               Madras Chicken 65 Boneless (1 Kg)
#             </a>
# </div>
# </div>
# </div><div _ngcontent-c7="" class="ng-star-inserted">
# <!-- --><!-- -->
# <div _ngcontent-c7="" class="container py-3 popular-cateogry ng-star-inserted">
# <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#             OILS
#           </p>
# <div _ngcontent-c7="" class="row py-1">
# <!-- --><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/virgin-groundnut-oil-1000ml?agentname=supriya" queryparamshandling="merge">
#               Virgin Groundnut Oil - 1000ML
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/virgin-groundnut-oil-500ml?agentname=supriya" queryparamshandling="merge">
#               Virgin Groundnut Oil - 500ML
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/virgin-coconut-oil-500ml?agentname=supriya" queryparamshandling="merge">
#               Virgin Coconut Oil - 500ML
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/virgin-sesame-oil-500ml?agentname=supriya" queryparamshandling="merge">
#               Virgin Sesame Oil - 500ML
#             </a><a _ngcontent-c7="" class="products-list px-3 mb-1 ng-star-inserted" href="/product/virgin-coconut-oil-1000ml?agentname=supriya" queryparamshandling="merge">
#               Virgin Coconut Oil - 1000ML
#             </a>
# </div>
# </div>
# </div>
# </mat-card>
# </div>
# </app-footer>
# </mat-drawer-content><!-- --></mat-drawer-container>
# </app-base-page>
# </app-root><script>var script = document.createElement('script');
#     script.src = 'https://wchat.freshchat.com/js/widget.js';
#     script.onload = function () {
#       window.fcWidget.init({
#         token: 'ebf2d2fb-c29c-4538-b019-949309e094e0',
#         host: 'https://wchat.freshchat.com',
#         config: {
#           showFAQOnOpen: false,
#           hideFAQ: false
#         }
#       });
#     };
#     document.body.appendChild(script);</script><script src="https://webcdn.tendercuts.in/inline.04dd4baee24149f3a00a.bundle.js" type="text/javascript"></script><script src="https://webcdn.tendercuts.in/polyfills.a7c714ebaed2b4e770f7.bundle.js" type="text/javascript"></script><script src="https://webcdn.tendercuts.in/scripts.a339ed75230f3d92aee3.bundle.js" type="text/javascript"></script><script src="https://webcdn.tendercuts.in/main.3ff46e73202ec5fa7481.bundle.js" type="text/javascript"></script><div aria-atomic="true" aria-live="polite" class="cdk-visually-hidden"></div></body></html>

# %%
name = soup("mat-card-title")

# %%
name
# Out:
# [<mat-card-title class="mat-card-title ng-tns-c9-3">Dry Seer Fish</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-3">Dry Seer Fish</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-4">Dry Ribbon Fish</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-4">Dry Ribbon Fish</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-5">Dry Nethili Fish ( Big Anchovies )</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-5">Dry Nethili Fish ( Big Anchovies )</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-6">Dry Sole Fish</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-6">Dry Sole Fish</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-7">Dry Shark Fish</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-7">Dry Shark Fish</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-8">Dry Nethili Fish ( Small Anchovies )</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-8">Dry Nethili Fish ( Small Anchovies )</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-9">Dry Prawns ( 80g )</mat-card-title>,
#  <mat-card-title class="mat-card-title ng-tns-c9-9">Dry Prawns ( 80g )</mat-card-title>]

# %%
name = soup("mat-card-title")
product=[]
for i in range(len(name)):
    product.append(name[i].string)
productList=[product[x] for x in range(len(product)) if product[x] not in product[x+1:]]

# %%
productList
# Out:
# ['Dry Seer Fish',
#  'Dry Ribbon Fish',
#  'Dry Nethili Fish ( Big Anchovies )',
#  'Dry Sole Fish',
#  'Dry Shark Fish',
#  'Dry Nethili Fish ( Small Anchovies )',
#  'Dry Prawns ( 80g )']

# %%
weight=soup("mat-card-content")
net_weights=[]
for j in range(len(weight)):
    weights=weight[j].get_text().replace("\n","")
    net_weights.append(re.sub("[:Weightms]","",weights))

# %%
net_weights
# Out:
# ['   1 Pack',
#  '   1 Pack',
#  '   1 Pack',
#  '   1 Pack',
#  '   1 Pack',
#  '   1 Pack',
#  '   1 Pack',
#  '"A do of kndn on your pla"']

# %%
price=soup("app-price-display")
net_price=[price[k].get_text().replace("\n","") for k in range(len(price)) if price[k] not in price[k+1:]]

# %%
net_price
# Out:
# ['      ₹120    ',
#  '      ₹60    ',
#  '      ₹120    ',
#  '      ₹50    ',
#  '      ₹70    ',
#  '      ₹60    ',
#  '      ₹75    ']

# %%
df=pd.DataFrame(productList,columns=['Name'])

# %%
df['Weight_in_gms']=pd.DataFrame(net_weights)

# %%
df['Selling_price'] = net_price

# %%
df
# Out:
#                                    Name Weight_in_gms   Selling_price
# 0                         Dry Seer Fish        1 Pack        ₹120
# 1                       Dry Ribbon Fish        1 Pack         ₹60
# 2    Dry Nethili Fish ( Big Anchovies )        1 Pack        ₹120
# 3                         Dry Sole Fish        1 Pack         ₹50
# 4                        Dry Shark Fish        1 Pack         ₹70
# 5  Dry Nethili Fish ( Small Anchovies )        1 Pack         ₹60
# 6                    Dry Prawns ( 80g )        1 Pack         ₹75

# %%
path="C:/Users/Azeem/Documents/Projects/Python-Projects/excel/tender_cuts_dryfish.csv"
if os.path.isfile == True:
    pass
else:
    df.to_csv(path,index=False)
