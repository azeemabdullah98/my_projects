# %%
import os
from datetime import datetime

# %%
print(dir(os))
# Out:
# ['DirEntry', 'F_OK', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_putenv', '_unsetenv', '_wrap_close', 'abc', 'abort', 'access', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 'get_exec_path', 'get_handle_inheritable', 'get_in
# ...

# %%
print(os.getcwd())
# Out:
# C:\Users\Azeem

# %%
os.chdir("C:/Users/Azeem/")

# %%
print(os.getcwd())
# Out:
# C:\Users\Azeem

# %%
os.mkdir("os-demo-2")

# %%
os.makedirs("os-demo-2/sub-dir-1/")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-22-38b28785260c> in <module>
# ----> 1 os.makedirs("os-demo-2/sub-dir-1/")
#
# c:\users\azeem\appdata\local\programs\python\python37\lib\os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'os-demo-2/sub-dir-1/'

# %%
os.rmdir("os-demo-2/sub-dir-1/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-2f9b7d83c834> in <module>
# ----> 1 os.rmdir("os-demo-2/sub-dir-1/")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'os-demo-2/sub-dir-1/'

# %%
os.removedirs("os-demo-2/")

# %%
os.rename("demo.txt","location.txt")

# %%
print(os.stat("location.txt"))
# Out:
# os.stat_result(st_mode=33206, st_ino=6192449487738076, st_dev=1141116617, st_nlink=1, st_uid=0, st_gid=0, st_size=61, st_atime=1614435922, st_mtime=1614435922, st_ctime=1614435922)

# %%
print(os.stat("location.txt").st_size)
# Out:
# 61

# %%
mod_time = os.stat("location.txt").st_mtime

# %%
print(datetime.fromtimestamp(mod_time))
# Out:
# 2021-02-27 19:55:22.739869

# %%
for dirpath ,dirname ,filename in os.walk("C:/Users/Azeem/VLC"):
    print("currentpaths:",dirpath)
    print("directories:",dirname)
    print("filenames:",filename)
    print()
# Out:
# currentpaths: C:/Users/Azeem/VLC
# directories: ['hrtfs', 'locale', 'lua', 'plugins', 'skins']
# filenames: ['AUTHORS.txt', 'axvlc.dll', 'COPYING.txt', 'Documentation.url', 'libvlc.dll', 'libvlccore.dll', 'NEWS.txt', 'New_Skins.url', 'npvlc.dll', 'README.txt', 'THANKS.txt', 'uninstall.exe', 'uninstall.log', 'VideoLAN Website.url', 'vlc-cache-gen.exe', 'vlc.exe']
#
# currentpaths: C:/Users/Azeem/VLC\hrtfs
# directories: []
# filenames: ['dodeca_and_7channel_3DSL_HRTF.sofa']
#
# currentpaths: C:/Users/Azeem/VLC\locale
# ...

# %%
print(os.environ.get("HOME"))
# Out:
# None

# %%
file_path = os.path.join(os.environ.get("HOME"),"test.txt")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-707d8f8184fe> in <module>
# ----> 1 file_path = os.path.join(os.environ.get("HOME"),"test.txt")
#
# c:\users\azeem\appdata\local\programs\python\python37\lib\ntpath.py in join(path, *paths)
#      74 # Join two (or more) paths.
#      75 def join(path, *paths):
# ---> 76     path = os.fspath(path)
#      77     if isinstance(path, bytes):
#      78         sep = b'\\'
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
os.path.basename("/tmp/test.txt")
# Out:
# 'test.txt'

# %%
os.path.dirname("/tmp/test.txt")
# Out:
# '/tmp'

# %%
os.path.split("/tmp/test.txt")
# Out:
# ('/tmp', 'test.txt')

# %%
os.path.exists("/tmp/test.txt")
# Out:
# False

# %%
os.path.isdir("/tmp/test.txt")
# Out:
# False

# %%
os.path.isfile("/tmp/test.txt")
# Out:
# False

# %%
os.path.splitext("/tmp/test.txt")
# Out:
# ('/tmp/test', '.txt')

# %%
print(dir(os.path))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_abspath_fallback', '_get_bothseps', '_getfinalpathname', '_getfullpathname', '_getvolumepathname', 'abspath', 'altsep', 'basename', 'commonpath', 'commonprefix', 'curdir', 'defpath', 'devnull', 'dirname', 'exists', 'expanduser', 'expandvars', 'extsep', 'genericpath', 'getatime', 'getctime', 'getmtime', 'getsize', 'isabs', 'isdir', 'isfile', 'islink', 'ismount', 'join', 'lexists', 'normcase', 'normpath', 'os', 'pardir', 'pathsep', 'realpath', 'relpath', 'samefile', 'sameopenfile', 'samestat', 'sep', 'split', 'splitdrive', 'splitext', 'stat', 'supports_unicode_filenames', 'sys']

# %%
print(os.listdir())
# Out:
# ['desktop.ini', 'location.txt', 'Microsoft Edge.lnk', 'Revo Uninstaller Pro.lnk', 'µTorrent.lnk']
