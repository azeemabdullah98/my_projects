# %% [markdown]
# # Types of web scrapping

# %% [markdown]
# ## BeautifulSoup,regular expression

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

# %%
url = "http://olympus.realpython.org/profiles/aphrodite"

# %%
page=urlopen(url)

# %%
page

# %%
html_bytes = page.read()

# %%
html = html_bytes.decode('utf-8')

# %%
print(html)
# Out:
# <html>
# <head>
# <title>Profile: Aphrodite</title>
# </head>
# <body bgcolor="yellow">
# <center>
# <br><br>
# <img src="/static/aphrodite.gif" />
# <h2>Name: Aphrodite</h2>
# <br><br>
# Favorite animal: Dove
# <br><br>
# Favorite color: Red
# <br><br>
# Hometown: Mount Olympus
# </center>
# </body>
# </html>

# %%
title_index = html.find("<title>")

# %%
print(title_index)
# Out:
# 14

# %%
start_index=len("<title>")+title_index
start_index
# Out:
# 21

# %%
end_index = html.find("</title>")
end_index
# Out:
# 39

# %%
title=html[start_index:end_index]
title
# Out:
# 'Profile: Aphrodite'

# %%
import requests

# %%
res=requests.get("https://automatetheboringstuff.com/files/rj.txt")

# %%
type(res)
# Out:
# requests.models.Response

# %%
len(res.text)
# Out:
# 178978

# %%
print(res.text[:250])
# Out:
# The Project Gutenberg EBook of Romeo and Juliet, by William Shakespeare
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Projec

# %%
print(res.raise_for_status())
# Out:
# None

# %%
html=BeautifulSoup(html,"html.parser")

# %%
html
# Out:
# <html>
# <head>
# <title>Profile: Poseidon</title>
# </head>
# <body bgcolor="yellow">
# <center>
# <br/><br/>
# <img src="/static/poseidon.jpg"/>
# <h2>Name: Poseidon</h2>
# <br/><br/>
# Favorite animal: Dolphin
# <br/><br/>
# Favorite color: Blue
# <br/><br/>
# Hometown: Sea
# </center>
# </body>
# </html>

# %%
data=re.sub("[^a-zA-Z]"," ",cleaned_data.get_text())

# %%
data
# Out:
# '  Profile  Poseidon      Name  Poseidon  Favorite animal  Dolphin  Favorite color  Blue  Hometown  Sea    '

# %% [markdown]
# ## Scrapy

# %% [markdown]
# ### Spider argument

# %%
import scrapy

# %%
class FirstSpider(scrapy.Spider):
    name="first"
    def __init__(self,group=None,*args,**kwargs):
        super(FirstSpider,self).__init___(*args,**kwargs)
        self.start_urls("http://tendercuts.in/%s"%group)

# %% [markdown]
# ### Generic Spider

# %%
import scrapy
from scrapy.item import Item,Field

class First_scrapyItem(scrapy.Item):
    product_title=Field()
    product_link=Field()
    product_description=Field()

# %% [markdown]
# ### CrawlSpider

# %%
import scrapy
from scrapy.spiders import CrawlSpider,Rule
from scrapy.linkextractors import LinkExtractor

# %%
import scrapy
from scrapy.spiders import CrawlSpider, Rule
from scrapy.linkextractors import LinkExtractor

class DemoSpider(CrawlSpider):
    name = "demo"
    allowed_domains = ["www.tendercuts.in"]
    start_urls = ["https://tendercuts.in"]
      
    rules = ( 
      Rule(LinkExtractor(allow =(), restrict_xpaths = ("//div[@class = 'next']",)),
         callback = "parse_item", follow = True),
   )
   
    def parse_item(self, response):
        item = DemoItem()
        item["product_title"] = response.xpath("a/text()").extract()
#         item["product_link"] = response.xpath("a/@href").extract()
#         item["product_description"] = response.xpath("div[@class = 'desc']/text()").extract()
        print(item)
        return item

# %% [markdown]
# ### CSVFeedSpider

# %%
from scrapy.spiders import CSVFeedSpider
from demoproject.items import DemoItem  

class DemoSpider(CSVFeedSpider): 
    name = "demo" 
    allowed_domains = ["www.demoexample.com"] 
    start_urls = ["http://www.demoexample.com/feed.csv"] 
    delimiter = ";" 
    quotechar = "'" 
    headers = ["product_title", "product_link", "product_description"]  
   
    def parse_row(self, response, row): 
        self.logger.info("This is row: %r", row)  
        item = DemoItem() 
        item["product_title"] = row["product_title"] 
        item["product_link"] = row["product_link"] 
        item["product_description"] = row["product_description"] 
        return item
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-8ec0737516d1> in <module>
#       1 from scrapy.spiders import CSVFeedSpider
# ----> 2 from demoproject.items import DemoItem
#       3
#       4 class DemoSpider(CSVFeedSpider):
#       5     name = "demo"
#
# ModuleNotFoundError: No module named 'demoproject'

# %% [markdown]
# ### SiteMap Spider

# %%
from scrapy.spiders import SitemapSpider
import scrapy

# %% [markdown]
# #### for all urls

# %%
from scrapy.spiders import SitemapSpider  

class DemoSpider(SitemapSpider): 
    urls = ["http://www.demoexample.com/sitemap.xml"]  
   
    def parse(self, response): 
      # You can scrap items here
# Out:
#   File "<ipython-input-11-40bdd281695d>", line 7
#     # You can scrap items here
#                               ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# #### for some urls with callback

# %%
class TenderCuts(scrapy.spiders.SitemapSpider):
    urls=["https://tendercuts.in/sitemap.xml"]
    rule=[
        ("/category/chicken","parse_chicken"),
        ("/category/mutton","parse_mutton")]
    def parse_chicken(self,response):
        title=list(response.xpath("div/class/mat-card-title").extract())
        weight=list(response.xpath("div/class/mat-card-content").extract())
        price=list(response.xpath("div/class/app-price-display").extract())
        return title,weight,price

# %%
from scrapy.http import HtmlResponse
from scrapy.selector import Selector
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
page=urlopen("https://tendercuts.in")
html=page.read().decode('utf-8')

# %%
html
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>Order Meat Online | Buy Fresh Chicken &amp; Fish Online - TenderCuts.in</title><base href="/"><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no"><meta name="description" content="Order tender, fresh, juicy &amp; safe meat &amp; seafood online from India\'s best online shop. Get products delivered to your homes in Chennai &amp; Hyderabad."><meta name="title" content="Order Meat Online | Buy Fresh Chicken &amp; Fish Online - TenderCuts.in"><link rel="icon" type="image/x-icon" href="favicon.ico"><link async="" href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"><script src="https://maps.googleapis.com/maps/api/js?v=3.exp&amp;libraries=places&amp;key=AIzaSyBGwX-cOb7BB4aJZaTFT7aD96LEQYdgRlw"></script><script src="https://webcdn.tendercuts.in/assets/js/intersect.js"></script><script async="" src="https://wchat.freshchat.com/js/widge
# ...

# %%
soup=BeautifulSoup(html,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
response
# Out:
# <200 https://tendercuts.in>

# %%
def parse(res):
    res.xpath("//div/a").extract()

# %%
import scrapy


class QuotesSpider(scrapy.Spider):
    name = "quotes"

    def start_requests(self):
        urls = [
            'http://quotes.toscrape.com/page/1/',
            'http://quotes.toscrape.com/page/2/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        page = response.url.split("/")[-2]
        filename = f'quotes-{page}.html'
        with open(filename, 'wb') as f:
            f.write(response.body)
        self.log(f'Saved file {filename}')

# %% [markdown]
# # Tender Cuts

# %%
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen

# %%
url="https://tendercuts.in/home"

# %%
page=urlopen(url)
html=page.read().decode('utf-8')

# %%
soup=BeautifulSoup(html,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
product_name=soup("p")
product_name
# Out:
# [<p _ngcontent-c29="" class="values-title"> Why TenderCuts ?</p>,
#  <p>Dry Fish</p>,
#  <p>Combo</p>,
#  <p>Chicken</p>,
#  <p>Mutton</p>,
#  <p>Sea Food</p>,
#  <p>Ready To Cook</p>,
#  <p>Cold Cuts</p>,
#  <p>Eggs</p>,
#  <p>Pickles</p>,
#  <p>Spices</p>,
#  <p>Party Pack</p>,
#  <p>Oils</p>,
#  <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#              DRY FISH
#            </p>,
#  <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#              COMBO
#            </p>,
#  <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#              CHICKEN
#            </p>,
#  <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#              MUTTON
#            </p>,
#  <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#              SEA FOOD
#            </p>,
#  <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#              READY TO COOK
#            </p>,
#  <p _ngcontent-c7="" class="row pl-3 cat-list-header">
#              COLD CUTS
#            </p>,
# ...

# %%
for i in range(len(product_name)):
    print(product_name[i].get_text())
# Out:
#  Why TenderCuts ?
# Dry Fish
# Combo
# Chicken
# Mutton
# Sea Food
# Ready To Cook
# Cold Cuts
# Eggs
# Pickles
# Spices
# Party Pack
# Oils
#
#             DRY FISH
#
#
#             COMBO
#
#
#             CHICKEN
#
#
#             MUTTON
#
#
#             SEA FOOD
#
#
#             READY TO COOK
#
#
#             COLD CUTS
#
#
#             EGGS
#
#
#             PICKLES
#
#
#             SPICES
#
#
#             PARTY PACK
#
#
#             OILS
